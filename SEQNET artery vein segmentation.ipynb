# %%
# Cell 1 - Run this FIRST and SEPARATELY
import subprocess
import os

# Kill any existing GPU processes
try:
    subprocess.run(['nvidia-smi', '--gpu-reset'], capture_output=True)
except:
    pass

# Clear CUDA cache
os.environ['CUDA_CACHE_PATH'] = '/tmp/cuda_cache'
os.environ['CUDA_CACHE_MAXSIZE'] = '1073741824'  # 1GB

# Prevent TensorFlow from allocating all GPU memory
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

print("GPU environment reset")
# Out:
# GPU environment reset

# %%
# !gdown --id '1OYjzu0gixtga6e7Rvb2mZoSSYJkXWRNB'
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1OYjzu0gixtga6e7Rvb2mZoSSYJkXWRNB
# From (redirected): https://drive.google.com/uc?id=1OYjzu0gixtga6e7Rvb2mZoSSYJkXWRNB&confirm=t&uuid=d03b896c-da04-450b-88ad-fe3b8b419d67
# To: /kaggle/working/Final_Emer_Iteration_3_cropsize_128_epochs_200.hdf5
# 100%|████████████████████████████████████████| 298M/298M [00:03<00:00, 98.5MB/s]

# %%
# !git clone https://github.com/conscienceli/SeqNet.git
# Out:
# Cloning into 'SeqNet'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 48 (delta 7), reused 6 (delta 6), pack-reused 37 (from 1)
# Receiving objects: 100% (48/48), 691.14 KiB | 5.67 MiB/s, done.
# Resolving deltas: 100% (15/15), done.

# %%
cd SeqNet
# Out:
# /kaggle/working/SeqNet

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import apply_affine_transform

def flip_axis(x, axis):
    # axis 1 = horizontal, axis 0 = vertical
    if axis == 1:
        return np.flip(x, axis=1)
    elif axis == 0:
        return np.flip(x, axis=0)
    else:
        raise ValueError("axis must be 0 (vertical) or 1 (horizontal)")

def random_flip(img, masks, masks2, u=0.5):
    if np.random.random() < u:
        img = flip_axis(img, 1)
        for i in range(masks.shape[0]):
            masks[i] = flip_axis(masks[i], 1)
        for i in range(masks2.shape[0]):
            masks2[i] = flip_axis(masks2[i], 1)
    if np.random.random() < u:
        img = flip_axis(img, 0)
        for i in range(masks.shape[0]):
            masks[i] = flip_axis(masks[i], 0)
        for i in range(masks2.shape[0]):
            masks2[i] = flip_axis(masks2[i], 0)
    return img, masks, masks2

def random_rotate(img, masks, masks2, rotate_limit=(-20, 20), u=0.5):
    if np.random.random() < u:
        theta = np.random.uniform(rotate_limit[0], rotate_limit[1])
        img = apply_affine_transform(img, theta=theta)
        for i in range(masks.shape[0]):
            masks[i] = apply_affine_transform(masks[i], theta=theta)
        for i in range(masks2.shape[0]):
            masks2[i] = apply_affine_transform(masks2[i], theta=theta)
    return img, masks, masks2

def shift(x, wshift, hshift, row_axis=0, col_axis=1, channel_axis=2, fill_mode='nearest', cval=0.):
    h, w = x.shape[row_axis], x.shape[col_axis]
    tx = hshift * h
    ty = wshift * w
    x = apply_affine_transform(x, ty=ty, tx=tx)
    return x

def random_shift(img, masks, masks2, w_limit=(-0.1, 0.1), h_limit=(-0.1, 0.1), u=0.5):
    if np.random.random() < u:
        wshift = np.random.uniform(w_limit[0], w_limit[1])
        hshift = np.random.uniform(h_limit[0], h_limit[1])
        img = shift(img, wshift, hshift)
        for i in range(masks.shape[0]):
            masks[i] = shift(masks[i], wshift, hshift)
        for i in range(masks2.shape[0]):
            masks2[i] = shift(masks2[i], wshift, hshift)
    return img, masks, masks2

def random_zoom(img, masks, masks2, zoom_range=(0.8, 1), u=0.5):
    if np.random.random() < u:
        zx, zy = np.random.uniform(zoom_range[0], zoom_range[1], 2)
        img = apply_affine_transform(img, zx=zx, zy=zy)
        for i in range(masks.shape[0]):
            masks[i] = apply_affine_transform(masks[i], zx=zx, zy=zy)
        for i in range(masks2.shape[0]):
            masks2[i] = apply_affine_transform(masks2[i], zx=zx, zy=zy)
    return img, masks, masks2

def random_shear(img, masks, masks2, intensity_range=(-0.5, 0.5), u=0.5):
    if np.random.random() < u:
        sh = np.random.uniform(intensity_range[0], intensity_range[1])
        img = apply_affine_transform(img, shear=sh)
        for i in range(masks.shape[0]):
            masks[i] = apply_affine_transform(masks[i], shear=sh)
        for i in range(masks2.shape[0]):
            masks2[i] = apply_affine_transform(masks2[i], shear=sh)
    return img, masks, masks2

def random_gray(img, u=0.5):
    if np.random.random() < u:
        coef = np.array([[[0.114, 0.587, 0.299]]])  # rgb to gray (YCbCr)
        gray = np.sum(img * coef, axis=2)
        img = np.dstack((gray, gray, gray))
    return img

def random_contrast(img, limit=(-0.3, 0.3), u=0.5):
    if np.random.random() < u:
        alpha = 1.0 + np.random.uniform(limit[0], limit[1])
        coef = np.array([[[0.114, 0.587, 0.299]]])
        gray = img * coef
        gray = (3.0 * (1.0 - alpha) / gray.size) * np.sum(gray)
        img = alpha * img + gray
        img = np.clip(img, 0., 1.)
    return img

def random_brightness(img, limit=(-0.3, 0.3), u=0.5):
    if np.random.random() < u:
        alpha = 1.0 + np.random.uniform(limit[0], limit[1])
        img = alpha * img
        img = np.clip(img, 0., 1.)
    return img

def random_saturation(img, limit=(-0.3, 0.3), u=0.5):
    if np.random.random() < u:
        alpha = 1.0 + np.random.uniform(limit[0], limit[1])
        coef = np.array([[[0.114, 0.587, 0.299]]])
        gray = img * coef
        gray = np.sum(gray, axis=2, keepdims=True)
        img = alpha * img + (1. - alpha) * gray
        img = np.clip(img, 0., 1.)
    return img

def random_channel_shift(x, limit, channel_axis=2):
    x = np.rollaxis(x, channel_axis, 0)
    min_x, max_x = np.min(x), np.max(x)
    channel_images = [np.clip(x_ch + np.random.uniform(-limit, limit), min_x, max_x) for x_ch in x]
    x = np.stack(channel_images, axis=0)
    x = np.rollaxis(x, 0, channel_axis + 1)
    return x

def random_augmentation(img, masks, masks2=None):
    img = random_brightness(img, limit=(-0.2, 0.2), u=0.5)
    img = random_contrast(img, limit=(-0.2, 0.2), u=0.5)
    img = random_saturation(img, limit=(-0.2, 0.2), u=0.5)
    img, masks, masks2 = random_rotate(img, masks, masks2, rotate_limit=(-180, 180), u=0.5)
    img, masks, masks2 = random_shear(img, masks, masks2, intensity_range=(-5, 5), u=0.05)
    img, masks, masks2 = random_flip(img, masks, masks2, u=0.5)
    img, masks, masks2 = random_shift(img, masks, masks2, w_limit=(-0.1, 0.1), h_limit=(-0.1, 0.1), u=0.05)
    img, masks, masks2 = random_zoom(img, masks, masks2, zoom_range=(0.8, 1.2), u=0.05)
    return img, masks, masks2
# Out:
# 2025-07-09 08:41:44.180280: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752050504.551311      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752050504.650698      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import h5py
import numpy as np
import os
import threading
from PIL import Image

import tensorflow as tf
from tensorflow.keras import backend as K, losses
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import (Input, MaxPooling2D, Lambda, concatenate,
                                     Conv2D, Conv2DTranspose, Dropout, ReLU,
                                     BatchNormalization, Activation, add, multiply)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

from numpy import random
from random import randint
from utils import prepare_dataset


def get_unet(minimum_kernel=32, do=0, activation=ReLU, iteration=1):
    inputs = Input((None, None, 3))
    conv1 = Dropout(do)(activation()(Conv2D(minimum_kernel, (3, 3), padding='same')(inputs)))
    conv1 = Dropout(do)(activation()(Conv2D(minimum_kernel, (3, 3), padding='same')(conv1)))
    a = conv1
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Dropout(do)(activation()(Conv2D(minimum_kernel * 2, (3, 3), padding='same')(pool1)))
    conv2 = Dropout(do)(activation()(Conv2D(minimum_kernel * 2, (3, 3), padding='same')(conv2)))
    b = conv2
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Dropout(do)(activation()(Conv2D(minimum_kernel * 4, (3, 3), padding='same')(pool2)))
    conv3 = Dropout(do)(activation()(Conv2D(minimum_kernel * 4, (3, 3), padding='same')(conv3)))
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Dropout(do)(activation()(Conv2D(minimum_kernel * 8, (3, 3), padding='same')(pool3)))
    conv4 = Dropout(do)(activation()(Conv2D(minimum_kernel * 8, (3, 3), padding='same')(conv4)))
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Dropout(do)(activation()(Conv2D(minimum_kernel * 16, (3, 3), padding='same')(pool4)))
    conv5 = Dropout(do)(activation()(Conv2D(minimum_kernel * 16, (3, 3), padding='same')(conv5)))

    up6 = concatenate([Conv2DTranspose(minimum_kernel * 8, (2, 2), strides=(2, 2), padding='same')(conv5), conv4],
                      axis=3)
    conv6 = Dropout(do)(activation()(Conv2D(minimum_kernel * 8, (3, 3), padding='same')(up6)))
    conv6 = Dropout(do)(activation()(Conv2D(minimum_kernel * 8, (3, 3), padding='same')(conv6)))

    up7 = concatenate([Conv2DTranspose(minimum_kernel * 4, (2, 2), strides=(2, 2), padding='same')(conv6), conv3],
                      axis=3)
    conv7 = Dropout(do)(activation()(Conv2D(minimum_kernel * 4, (3, 3), padding='same')(up7)))
    conv7 = Dropout(do)(activation()(Conv2D(minimum_kernel * 4, (3, 3), padding='same')(conv7)))

    up8 = concatenate([Conv2DTranspose(minimum_kernel * 2, (2, 2), strides=(2, 2), padding='same')(conv7), conv2],
                      axis=3)
    conv8 = Dropout(do)(activation()(Conv2D(minimum_kernel * 2, (3, 3), padding='same')(up8)))
    conv8 = Dropout(do)(activation()(Conv2D(minimum_kernel * 2, (3, 3), padding='same')(conv8)))

    up9 = concatenate([Conv2DTranspose(minimum_kernel, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Dropout(do)(activation()(Conv2D(minimum_kernel, (3, 3), padding='same')(up9)))
    conv9 = Dropout(do)(activation()(Conv2D(minimum_kernel, (3, 3), padding='same')(conv9)))

    pt_conv1a = Conv2D(minimum_kernel, (3, 3), padding='same')
    pt_activation1a = activation()
    pt_dropout1a = Dropout(do)
    pt_conv1b = Conv2D(minimum_kernel, (3, 3), padding='same')
    pt_activation1b = activation()
    pt_dropout1b = Dropout(do)
    pt_pooling1 = MaxPooling2D(pool_size=(2, 2))

    pt_conv2a = Conv2D(minimum_kernel * 2, (3, 3), padding='same')
    pt_activation2a = activation()
    pt_dropout2a = Dropout(do)
    pt_conv2b = Conv2D(minimum_kernel * 2, (3, 3), padding='same')
    pt_activation2b = activation()
    pt_dropout2b = Dropout(do)
    pt_pooling2 = MaxPooling2D(pool_size=(2, 2))

    pt_conv3a = Conv2D(minimum_kernel * 4, (3, 3), padding='same')
    pt_activation3a = activation()
    pt_dropout3a = Dropout(do)
    pt_conv3b = Conv2D(minimum_kernel * 4, (3, 3), padding='same')
    pt_activation3b = activation()
    pt_dropout3b = Dropout(do)

    pt_tranconv8 = Conv2DTranspose(minimum_kernel * 2, (2, 2), strides=(2, 2), padding='same')
    pt_conv8a = Conv2D(minimum_kernel * 2, (3, 3), padding='same')
    pt_activation8a = activation()
    pt_dropout8a = Dropout(do)
    pt_conv8b = Conv2D(minimum_kernel * 2, (3, 3), padding='same')
    pt_activation8b = activation()
    pt_dropout8b = Dropout(do)

    pt_tranconv9 = Conv2DTranspose(minimum_kernel, (2, 2), strides=(2, 2), padding='same')
    pt_conv9a = Conv2D(minimum_kernel, (3, 3), padding='same')
    pt_activation9a = activation()
    pt_dropout9a = Dropout(do)
    pt_conv9b = Conv2D(minimum_kernel, (3, 3), padding='same')
    pt_activation9b = activation()
    pt_dropout9b = Dropout(do)

    conv9s = [conv9]
    outs = []
    a_layers = [a]
    for iteration_id in range(iteration):
        out = Conv2D(1, (1, 1), activation='sigmoid', name=f'out1{iteration_id + 1}')(conv9s[-1])
        outs.append(out)

        conv1 = pt_dropout1a(pt_activation1a(pt_conv1a(conv9s[-1])))
        conv1 = pt_dropout1b(pt_activation1b(pt_conv1b(conv1)))
        a_layers.append(conv1)
        conv1 = concatenate(a_layers, axis=3)
        conv1 = Conv2D(minimum_kernel, (1, 1), padding='same')(conv1)
        pool1 = pt_pooling1(conv1)

        conv2 = pt_dropout2a(pt_activation2a(pt_conv2a(pool1)))
        conv2 = pt_dropout2b(pt_activation2b(pt_conv2b(conv2)))
        pool2 = pt_pooling2(conv2)

        conv3 = pt_dropout3a(pt_activation3a(pt_conv3a(pool2)))
        conv3 = pt_dropout3b(pt_activation3b(pt_conv3b(conv3)))

        up8 = concatenate([pt_tranconv8(conv3), conv2], axis=3)
        conv8 = pt_dropout8a(pt_activation8a(pt_conv8a(up8)))
        conv8 = pt_dropout8b(pt_activation8b(pt_conv8b(conv8)))

        up9 = concatenate([pt_tranconv9(conv8), conv1], axis=3)
        conv9 = pt_dropout9a(pt_activation9a(pt_conv9a(up9)))
        conv9 = pt_dropout9b(pt_activation9b(pt_conv9b(conv9)))

        conv9s.append(conv9)

    seg_final_out = Conv2D(1, (1, 1), activation='sigmoid', name='seg_final_out')(conv9)
    outs.append(seg_final_out)

    # to cls
    def masked_input(args):
        x, inputs = args
        return x * inputs
    cls_in = Lambda(masked_input)([seg_final_out, inputs])
    # cls_in = concatenate([cls_in, crossing_final_out], axis=3)
    cls_in = Lambda(lambda x: K.stop_gradient(x))(cls_in)

    # to cls (artery)
    conv1 = Dropout(do)(activation()(Conv2D(minimum_kernel, (3, 3), padding='same')(cls_in)))
    conv1 = Dropout(do)(activation()(Conv2D(minimum_kernel, (3, 3), padding='same')(conv1)))
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Dropout(do)(activation()(Conv2D(minimum_kernel * 2, (3, 3), padding='same')(pool1)))
    conv2 = Dropout(do)(activation()(Conv2D(minimum_kernel * 2, (3, 3), padding='same')(conv2)))
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Dropout(do)(activation()(Conv2D(minimum_kernel * 4, (3, 3), padding='same')(pool2)))
    conv3 = Dropout(do)(activation()(Conv2D(minimum_kernel * 4, (3, 3), padding='same')(conv3)))
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Dropout(do)(activation()(Conv2D(minimum_kernel * 8, (3, 3), padding='same')(pool3)))
    conv4 = Dropout(do)(activation()(Conv2D(minimum_kernel * 8, (3, 3), padding='same')(conv4)))
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Dropout(do)(activation()(Conv2D(minimum_kernel * 16, (3, 3), padding='same')(pool4)))
    conv5 = Dropout(do)(activation()(Conv2D(minimum_kernel * 16, (3, 3), padding='same')(conv5)))

    up6 = concatenate([Conv2DTranspose(minimum_kernel * 8, (2, 2), strides=(2, 2), padding='same')(conv5), conv4],
                      axis=3)
    conv6 = Dropout(do)(activation()(Conv2D(minimum_kernel * 8, (3, 3), padding='same')(up6)))
    conv6 = Dropout(do)(activation()(Conv2D(minimum_kernel * 8, (3, 3), padding='same')(conv6)))

    up7 = concatenate([Conv2DTranspose(minimum_kernel * 4, (2, 2), strides=(2, 2), padding='same')(conv6), conv3],
                      axis=3)
    conv7 = Dropout(do)(activation()(Conv2D(minimum_kernel * 4, (3, 3), padding='same')(up7)))
    conv7 = Dropout(do)(activation()(Conv2D(minimum_kernel * 4, (3, 3), padding='same')(conv7)))

    up8 = concatenate([Conv2DTranspose(minimum_kernel * 2, (2, 2), strides=(2, 2), padding='same')(conv7), conv2],
                      axis=3)
    conv8 = Dropout(do)(activation()(Conv2D(minimum_kernel * 2, (3, 3), padding='same')(up8)))
    conv8 = Dropout(do)(activation()(Conv2D(minimum_kernel * 2, (3, 3), padding='same')(conv8)))

    up9 = concatenate([Conv2DTranspose(minimum_kernel, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Dropout(do)(activation()(Conv2D(minimum_kernel, (3, 3), padding='same')(up9)))
    conv9 = Dropout(do)(activation()(Conv2D(minimum_kernel, (3, 3), padding='same')(conv9)))


    pt_cls_art_conv1a = Conv2D(minimum_kernel, (3, 3), padding='same')
    pt_cls_art_activation1a = activation()
    pt_cls_art_dropout1a = Dropout(do)
    pt_cls_art_conv1b = Conv2D(minimum_kernel, (3, 3), padding='same')
    pt_cls_art_activation1b = activation()
    pt_cls_art_dropout1b = Dropout(do)
    pt_cls_art_pooling1 = MaxPooling2D(pool_size=(2, 2))

    pt_cls_art_conv2a = Conv2D(minimum_kernel * 2, (3, 3), padding='same')
    pt_cls_art_activation2a = activation()
    pt_cls_art_dropout2a = Dropout(do)
    pt_cls_art_conv2b = Conv2D(minimum_kernel * 2, (3, 3), padding='same')
    pt_cls_art_activation2b = activation()
    pt_cls_art_dropout2b = Dropout(do)
    pt_cls_art_pooling2 = MaxPooling2D(pool_size=(2, 2))

    pt_cls_art_conv3a = Conv2D(minimum_kernel * 4, (3, 3), padding='same')
    pt_cls_art_activation3a = activation()
    pt_cls_art_dropout3a = Dropout(do)
    pt_cls_art_conv3b = Conv2D(minimum_kernel * 4, (3, 3), padding='same')
    pt_cls_art_activation3b = activation()
    pt_cls_art_dropout3b = Dropout(do)

    pt_cls_art_tranconv8 = Conv2DTranspose(minimum_kernel * 2, (2, 2), strides=(2, 2), padding='same')
    pt_cls_art_conv8a = Conv2D(minimum_kernel * 2, (3, 3), padding='same')
    pt_cls_art_activation8a = activation()
    pt_cls_art_dropout8a = Dropout(do)
    pt_cls_art_conv8b = Conv2D(minimum_kernel * 2, (3, 3), padding='same')
    pt_cls_art_activation8b = activation()
    pt_cls_art_dropout8b = Dropout(do)

    pt_cls_art_tranconv9 = Conv2DTranspose(minimum_kernel, (2, 2), strides=(2, 2), padding='same')
    pt_cls_art_conv9a = Conv2D(minimum_kernel, (3, 3), padding='same')
    pt_cls_art_activation9a = activation()
    pt_cls_art_dropout9a = Dropout(do)
    pt_cls_art_conv9b = Conv2D(minimum_kernel, (3, 3), padding='same')
    pt_cls_art_activation9b = activation()
    pt_cls_art_dropout9b = Dropout(do)

    conv9s_cls_art = [conv9]
    a_layers = [a]
    for iteration_id in range(iteration):
        out = Conv2D(1, (1, 1), activation='sigmoid', name=f'out1_cls_art{iteration_id + 1}')(conv9s_cls_art[-1])
        outs.append(out)

        conv1 = pt_cls_art_dropout1a(pt_cls_art_activation1a(pt_cls_art_conv1a(conv9s_cls_art[-1])))
        conv1 = pt_cls_art_dropout1b(pt_cls_art_activation1b(pt_cls_art_conv1b(conv1)))
        a_layers.append(conv1)
        conv1 = concatenate(a_layers, axis=3)
        conv1 = Conv2D(minimum_kernel, (1, 1), padding='same')(conv1)
        pool1 = pt_cls_art_pooling1(conv1)

        conv2 = pt_cls_art_dropout2a(pt_cls_art_activation2a(pt_cls_art_conv2a(pool1)))
        conv2 = pt_cls_art_dropout2b(pt_cls_art_activation2b(pt_cls_art_conv2b(conv2)))
        pool2 = pt_cls_art_pooling2(conv2)

        conv3 = pt_cls_art_dropout3a(pt_cls_art_activation3a(pt_cls_art_conv3a(pool2)))
        conv3 = pt_cls_art_dropout3b(pt_cls_art_activation3b(pt_cls_art_conv3b(conv3)))

        up8 = concatenate([pt_cls_art_tranconv8(conv3), conv2], axis=3)
        conv8 = pt_cls_art_dropout8a(pt_cls_art_activation8a(pt_cls_art_conv8a(up8)))
        conv8 = pt_cls_art_dropout8b(pt_cls_art_activation8b(pt_cls_art_conv8b(conv8)))

        up9 = concatenate([pt_cls_art_tranconv9(conv8), conv1], axis=3)
        conv9 = pt_cls_art_dropout9a(pt_cls_art_activation9a(pt_cls_art_conv9a(up9)))
        conv9 = pt_cls_art_dropout9b(pt_cls_art_activation9b(pt_cls_art_conv9b(conv9)))

        conv9s_cls_art.append(conv9)


    cls_art_final_out = Conv2D(1, (1, 1), activation='sigmoid', name='cls_art_final_out')(conv9)

    outs.append(cls_art_final_out)


    # to cls (vein)
    conv1 = Dropout(do)(activation()(Conv2D(minimum_kernel, (3, 3), padding='same')(cls_in)))
    conv1 = Dropout(do)(activation()(Conv2D(minimum_kernel, (3, 3), padding='same')(conv1)))
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Dropout(do)(activation()(Conv2D(minimum_kernel * 2, (3, 3), padding='same')(pool1)))
    conv2 = Dropout(do)(activation()(Conv2D(minimum_kernel * 2, (3, 3), padding='same')(conv2)))
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Dropout(do)(activation()(Conv2D(minimum_kernel * 4, (3, 3), padding='same')(pool2)))
    conv3 = Dropout(do)(activation()(Conv2D(minimum_kernel * 4, (3, 3), padding='same')(conv3)))
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Dropout(do)(activation()(Conv2D(minimum_kernel * 8, (3, 3), padding='same')(pool3)))
    conv4 = Dropout(do)(activation()(Conv2D(minimum_kernel * 8, (3, 3), padding='same')(conv4)))
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Dropout(do)(activation()(Conv2D(minimum_kernel * 16, (3, 3), padding='same')(pool4)))
    conv5 = Dropout(do)(activation()(Conv2D(minimum_kernel * 16, (3, 3), padding='same')(conv5)))

    up6 = concatenate([Conv2DTranspose(minimum_kernel * 8, (2, 2), strides=(2, 2), padding='same')(conv5), conv4],
                      axis=3)
    conv6 = Dropout(do)(activation()(Conv2D(minimum_kernel * 8, (3, 3), padding='same')(up6)))
    conv6 = Dropout(do)(activation()(Conv2D(minimum_kernel * 8, (3, 3), padding='same')(conv6)))

    up7 = concatenate([Conv2DTranspose(minimum_kernel * 4, (2, 2), strides=(2, 2), padding='same')(conv6), conv3],
                      axis=3)
    conv7 = Dropout(do)(activation()(Conv2D(minimum_kernel * 4, (3, 3), padding='same')(up7)))
    conv7 = Dropout(do)(activation()(Conv2D(minimum_kernel * 4, (3, 3), padding='same')(conv7)))

    up8 = concatenate([Conv2DTranspose(minimum_kernel * 2, (2, 2), strides=(2, 2), padding='same')(conv7), conv2],
                      axis=3)
    conv8 = Dropout(do)(activation()(Conv2D(minimum_kernel * 2, (3, 3), padding='same')(up8)))
    conv8 = Dropout(do)(activation()(Conv2D(minimum_kernel * 2, (3, 3), padding='same')(conv8)))

    up9 = concatenate([Conv2DTranspose(minimum_kernel, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Dropout(do)(activation()(Conv2D(minimum_kernel, (3, 3), padding='same')(up9)))
    conv9 = Dropout(do)(activation()(Conv2D(minimum_kernel, (3, 3), padding='same')(conv9)))


    pt_cls_vei_conv1a = Conv2D(minimum_kernel, (3, 3), padding='same')
    pt_cls_vei_activation1a = activation()
    pt_cls_vei_dropout1a = Dropout(do)
    pt_cls_vei_conv1b = Conv2D(minimum_kernel, (3, 3), padding='same')
    pt_cls_vei_activation1b = activation()
    pt_cls_vei_dropout1b = Dropout(do)
    pt_cls_vei_pooling1 = MaxPooling2D(pool_size=(2, 2))

    pt_cls_vei_conv2a = Conv2D(minimum_kernel * 2, (3, 3), padding='same')
    pt_cls_vei_activation2a = activation()
    pt_cls_vei_dropout2a = Dropout(do)
    pt_cls_vei_conv2b = Conv2D(minimum_kernel * 2, (3, 3), padding='same')
    pt_cls_vei_activation2b = activation()
    pt_cls_vei_dropout2b = Dropout(do)
    pt_cls_vei_pooling2 = MaxPooling2D(pool_size=(2, 2))

    pt_cls_vei_conv3a = Conv2D(minimum_kernel * 4, (3, 3), padding='same')
    pt_cls_vei_activation3a = activation()
    pt_cls_vei_dropout3a = Dropout(do)
    pt_cls_vei_conv3b = Conv2D(minimum_kernel * 4, (3, 3), padding='same')
    pt_cls_vei_activation3b = activation()
    pt_cls_vei_dropout3b = Dropout(do)

    pt_cls_vei_tranconv8 = Conv2DTranspose(minimum_kernel * 2, (2, 2), strides=(2, 2), padding='same')
    pt_cls_vei_conv8a = Conv2D(minimum_kernel * 2, (3, 3), padding='same')
    pt_cls_vei_activation8a = activation()
    pt_cls_vei_dropout8a = Dropout(do)
    pt_cls_vei_conv8b = Conv2D(minimum_kernel * 2, (3, 3), padding='same')
    pt_cls_vei_activation8b = activation()
    pt_cls_vei_dropout8b = Dropout(do)

    pt_cls_vei_tranconv9 = Conv2DTranspose(minimum_kernel, (2, 2), strides=(2, 2), padding='same')
    pt_cls_vei_conv9a = Conv2D(minimum_kernel, (3, 3), padding='same')
    pt_cls_vei_activation9a = activation()
    pt_cls_vei_dropout9a = Dropout(do)
    pt_cls_vei_conv9b = Conv2D(minimum_kernel, (3, 3), padding='same')
    pt_cls_vei_activation9b = activation()
    pt_cls_vei_dropout9b = Dropout(do)

    conv9s_cls_vei = [conv9]
    a_layers = [a]
    for iteration_id in range(iteration):
        out = Conv2D(1, (1, 1), activation='sigmoid', name=f'out1_cls_vei{iteration_id + 1}')(conv9s_cls_vei[-1])
        outs.append(out)

        conv1 = pt_cls_vei_dropout1a(pt_cls_vei_activation1a(pt_cls_vei_conv1a(conv9s_cls_vei[-1])))
        conv1 = pt_cls_vei_dropout1b(pt_cls_vei_activation1b(pt_cls_vei_conv1b(conv1)))
        a_layers.append(conv1)
        conv1 = concatenate(a_layers, axis=3)
        conv1 = Conv2D(minimum_kernel, (1, 1), padding='same')(conv1)
        pool1 = pt_cls_vei_pooling1(conv1)

        conv2 = pt_cls_vei_dropout2a(pt_cls_vei_activation2a(pt_cls_vei_conv2a(pool1)))
        conv2 = pt_cls_vei_dropout2b(pt_cls_vei_activation2b(pt_cls_vei_conv2b(conv2)))
        pool2 = pt_cls_vei_pooling2(conv2)

        conv3 = pt_cls_vei_dropout3a(pt_cls_vei_activation3a(pt_cls_vei_conv3a(pool2)))
        conv3 = pt_cls_vei_dropout3b(pt_cls_vei_activation3b(pt_cls_vei_conv3b(conv3)))

        up8 = concatenate([pt_cls_vei_tranconv8(conv3), conv2], axis=3)
        conv8 = pt_cls_vei_dropout8a(pt_cls_vei_activation8a(pt_cls_vei_conv8a(up8)))
        conv8 = pt_cls_vei_dropout8b(pt_cls_vei_activation8b(pt_cls_vei_conv8b(conv8)))

        up9 = concatenate([pt_cls_vei_tranconv9(conv8), conv1], axis=3)
        conv9 = pt_cls_vei_dropout9a(pt_cls_vei_activation9a(pt_cls_vei_conv9a(up9)))
        conv9 = pt_cls_vei_dropout9b(pt_cls_vei_activation9b(pt_cls_vei_conv9b(conv9)))

        conv9s_cls_vei.append(conv9)


    cls_vei_final_out = Conv2D(1, (1, 1), activation='sigmoid', name='cls_vei_final_out')(conv9)

    outs.append(cls_vei_final_out)


    model = Model(inputs=[inputs], outputs=outs)


    loss_funcs = {}
    for iteration_id in range(iteration):
        loss_funcs.update({f'out1{iteration_id + 1}': losses.binary_crossentropy})
    loss_funcs.update({'seg_final_out': losses.binary_crossentropy})
    loss_funcs.update({'cls_art_final_out': losses.binary_crossentropy})
    loss_funcs.update({'cls_vei_final_out': losses.binary_crossentropy})
    for iteration_id in range(iteration):
        loss_funcs.update({f'out1_cls_art{iteration_id + 1}': losses.binary_crossentropy})
    for iteration_id in range(iteration):
        loss_funcs.update({f'out1_cls_vei{iteration_id + 1}': losses.binary_crossentropy})
  
    metrics = {
        "seg_final_out": ['accuracy'],
        "cls_art_final_out": ['accuracy'],
        "cls_vei_final_out": ['accuracy'],
    }

    model.compile(optimizer=Adam(learning_rate=1e-3), loss=loss_funcs, metrics=metrics)

    return model


def random_crop(img, mask, mask_onehot, crop_size):
    imgheight = img.shape[0]
    imgwidth = img.shape[1]

    i = randint(0, imgheight - crop_size)
    j = randint(0, imgwidth - crop_size)

    return img[i:(i + crop_size), j:(j + crop_size), :]\
            , np.array(mask)[:, i:(i + crop_size), j:(j + crop_size)]\
            , np.array(mask_onehot)[:, i:(i + crop_size), j:(j + crop_size)]


class Generator():
    def __init__(self, batch_size, repeat, dataset):
        self.lock = threading.Lock()
        self.dataset = dataset
        with self.lock:
            self.list_images_all = prepare_dataset.getTrainingData(0, self.dataset)
            self.list_gt_all = prepare_dataset.getTrainingData(1, self.dataset)
            self.list_gt_all_onehot = prepare_dataset.getTrainingData(1, self.dataset, need_one_hot=True)
        self.n = len(self.list_images_all)
        self.index = 0
        self.repeat = repeat
        self.batch_size = batch_size
        self.step = self.batch_size // self.repeat

        if self.repeat >= self.batch_size:
            self.repeat = self.batch_size
            self.step = 1

    def gen(self, au=True, crop_size=48, iteration=None):

        while True:
            data_yield = [self.index % self.n,
                          (self.index + self.step) % self.n if (self.index + self.step) < self.n else self.n]
            self.index = (self.index + self.step) % self.n

            list_images_base = self.list_images_all[data_yield[0]:data_yield[1]]
            list_gt_base = self.list_gt_all[data_yield[0]:data_yield[1]]
            list_gt_onehot_base = self.list_gt_all_onehot[data_yield[0]:data_yield[1]]

            list_images_aug = []
            list_gt_aug = []
            list_gt_onehot_aug = []
            image_id = -1
            for image, gt in zip(list_images_base, list_gt_base):
                image_id += 1
                gt2 = list_gt_onehot_base[image_id]
                if au:
                    if crop_size == prepare_dataset.DESIRED_DATA_SHAPE[0]:
                        for _ in range(self.repeat):
                            image, gt, gt2 = data_augmentation.random_augmentation(image, gt, gt2)
                            list_images_aug.append(image)
                            list_gt_aug.append(gt)
                            list_gt_onehot_aug.append(gt2)
                    else:
                        image, gt, gt2 = data_augmentation.random_augmentation(image, gt, gt2)
                        list_images_aug.append(image)
                        list_gt_aug.append(gt)
                        list_gt_onehot_aug.append(gt2)
                else:
                    list_images_aug.append(image)
                    list_gt_aug.append(gt)
                    list_gt_onehot_aug.append(gt2)

            list_images = []
            list_gt = []
            list_gt_onehot = []
            image_id = -1
            if crop_size == prepare_dataset.DESIRED_DATA_SHAPE[0]:
                list_images = list_images_aug
                list_gt = list_gt_aug
                list_gt_onehot = list_gt_onehot_aug
            else:
                for image, gt in zip(list_images_aug, list_gt_aug):
                    image_id += 1
                    for _ in range(self.repeat):
                        image_, gt_, gt_onehot_ = random_crop(image, gt, list_gt_onehot_aug[image_id], crop_size)

                        list_images.append(image_)
                        list_gt.append(gt_)
                        list_gt_onehot.append(gt_onehot_)

            outs = {}
            for iteration_id in range(iteration):
                outs.update({f'out1{iteration_id + 1}': np.array(list_gt)[:,0]})
            outs.update({'seg_final_out': np.array(list_gt)[:,0]})
            # outs.update({'crossing_final_out': np.array(list_gt)[:,1]})
            outs.update({'cls_art_final_out': np.array(list_gt)[:,2]})
            outs.update({'cls_vei_final_out': np.array(list_gt)[:,3]})
            for iteration_id in range(iteration):
                outs.update({f'out1_cls_art{iteration_id + 1}': np.array(list_gt)[:,2]})
            for iteration_id in range(iteration):
                outs.update({f'out1_cls_vei{iteration_id + 1}': np.array(list_gt)[:,3]})
            yield np.array(list_images), outs

# %%
import gc
import tensorflow as tf
from tensorflow.keras.layers import ReLU
from utils import crop_prediction
import numpy as np
from skimage.transform import resize
import cv2
from PIL import Image
import os

# Set up GPU memory growth
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except Exception as e:
        print(e)

def predict_single_image(image_path, output_dir, iteration=3, crop_size=128, stride_size=3):
    # Create output directories
    os.makedirs(f"{output_dir}/out_seg/", exist_ok=True)
    os.makedirs(f"{output_dir}/out_art/", exist_ok=True)
    os.makedirs(f"{output_dir}/out_vei/", exist_ok=True)
    os.makedirs(f"{output_dir}/out_final/", exist_ok=True)
    
    # Load model
    print("Loading model...")
    model = get_unet(minimum_kernel=32, do=0.1, activation=ReLU, iteration=iteration)
    model.load_weights("/kaggle/working/Final_Emer_Iteration_3_cropsize_128_epochs_200.hdf5")
    
    # Load and preprocess image
    print("Loading image...")
    filename = os.path.basename(image_path).split('.')[0]
    img = Image.open(image_path)
    image_size = img.size
    img = np.array(img) / 255.
    img = resize(img, [576, 576])
    
    # Get patches
    print("Creating patches...")
    patches_pred, new_height, new_width, _ = crop_prediction.get_test_patches(img, crop_size, stride_size)
    print(f"Total patches: {len(patches_pred)}")
    
    # Predict in small batches to save memory
    print("Predicting...")
    batch_size = 4  # Adjust this if needed
    all_preds = []
    
    for i in range(0, len(patches_pred), batch_size):
        batch = patches_pred[i:i+batch_size]
        batch_preds = model.predict(batch, verbose=0)
        all_preds.append(batch_preds)
        print(f"Processed {min(i+batch_size, len(patches_pred))}/{len(patches_pred)} patches")
        del batch
        gc.collect()
    
    # Combine predictions
    preds = []
    num_outputs = len(all_preds[0])
    for output_idx in range(num_outputs):
        output_preds = [pred[output_idx] for pred in all_preds]
        preds.append(np.concatenate(output_preds, axis=0))
    
    del all_preds, patches_pred
    gc.collect()
    
    print("Processing outputs...")
    
    # Process segmentation
    pred = preds[iteration]
    pred_patches = crop_prediction.pred_to_patches(pred, crop_size, stride_size)
    pred_imgs = crop_prediction.recompone_overlap(pred_patches, crop_size, stride_size, new_height, new_width)
    pred_seg = pred_imgs[0, :576, :576, 0]
    pred_seg = 255. * (pred_seg - np.min(pred_seg)) / (np.max(pred_seg) - np.min(pred_seg))
    cv2.imwrite(f"{output_dir}/out_seg/{filename}.png", resize(pred_seg, image_size[::-1], order=1))
    
    # Process artery
    pred = preds[2*iteration + 1]
    pred_patches = crop_prediction.pred_to_patches(pred, crop_size, stride_size)
    pred_imgs = crop_prediction.recompone_overlap(pred_patches, crop_size, stride_size, new_height, new_width)
    pred_art = pred_imgs[0, :576, :576, 0]
    pred_art = 255. * (pred_art - np.min(pred_art)) / (np.max(pred_art) - np.min(pred_art))
    cv2.imwrite(f"{output_dir}/out_art/{filename}.png", resize(pred_art, image_size[::-1], order=1))
    
    # Process vein
    pred = preds[3*iteration + 2]
    pred_patches = crop_prediction.pred_to_patches(pred, crop_size, stride_size)
    pred_imgs = crop_prediction.recompone_overlap(pred_patches, crop_size, stride_size, new_height, new_width)
    pred_vei = pred_imgs[0, :576, :576, 0]
    pred_vei = 255. * (pred_vei - np.min(pred_vei)) / (np.max(pred_vei) - np.min(pred_vei))
    cv2.imwrite(f"{output_dir}/out_vei/{filename}.png", resize(pred_vei, image_size[::-1], order=1))
    
    # Create final colored output
    pred_final = np.zeros((pred_seg.shape[0], pred_seg.shape[1], 3), dtype=np.float32)
    pred_final[(pred_art >= pred_vei), 2] = pred_seg[(pred_art >= pred_vei)]
    pred_final[(pred_art < pred_vei), 0] = pred_seg[(pred_art < pred_vei)]
    cv2.imwrite(f"{output_dir}/out_final/{filename}.png", resize(pred_final, image_size[::-1], order=1))
    
    print("Done!")

# Run prediction on single image
#for i in os.listdir('/kaggle/working/PVBM_datasets/INSPIRE/images'):
predict_single_image(
    image_path='/kaggle/input/imagess/image11.png',  # Change this to your image path
    output_dir='/kaggle/working',
    stride_size=32  # Increase this to reduce memory usage (3 is more accurate but uses more memory)
)
# Out:
# Loading model...
# I0000 00:00:1752050524.102034      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1752050524.102782      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Loading image...
# Creating patches...
# Total patches: 225
# Predicting...
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(4, 128, 128, 3))
#   warnings.warn(msg)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752050531.037209     114 service.cc:148] XLA service 0x7c3820004740 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1752050531.038903     114 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1752050531.038922     114 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1752050531.976924     114 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1752050536.235295     114 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Processed 4/225 patches
# Processed 8/225 patches
# Processed 12/225 patches
# Processed 16/225 patches
# Processed 20/225 patches
# Processed 24/225 patches
# Processed 28/225 patches
# Processed 32/225 patches
# Processed 36/225 patches
# Processed 40/225 patches
# Processed 44/225 patches
# Processed 48/225 patches
# Processed 52/225 patches
# Processed 56/225 patches
# Processed 60/225 patches
# Processed 64/225 patches
# Processed 68/225 patches
# Processed 72/225 patches
# Processed 76/225 patches
# Processed 80/225 patches
# Processed 84/225 patches
# Processed 88/225 patches
# Processed 92/225 patches
# Processed 96/225 patches
# Processed 100/225 patches
# Processed 104/225 patches
# Processed 108/225 patches
# Processed 112/225 patches
# Processed 116/225 patches
# Processed 120/225 patches
# Processed 124/225 patches
# Processed 128/225 patches
# Processed 132/225 patches
# Processed 136/225 patches
# Processed 140/225 patches
# Processed 144/225 patches
# Processed 148/225 patches
# Processed 152/225 patches
# Processed 156/225 patches
# Processed 160/225 patches
# Processed 164/225 patches
# Processed 168/225 patches
# Processed 172/225 patches
# Processed 176/225 patches
# Processed 180/225 patches
# Processed 184/225 patches
# Processed 188/225 patches
# Processed 192/225 patches
# Processed 196/225 patches
# Processed 200/225 patches
# Processed 204/225 patches
# Processed 208/225 patches
# Processed 212/225 patches
# Processed 216/225 patches
# Processed 220/225 patches
# Processed 224/225 patches
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 128, 128, 3))
#   warnings.warn(msg)
# Processed 225/225 patches
# Processing outputs...
# [ WARN:0@46.400] global loadsave.cpp:848 imwrite_ Unsupported depth image for selected encoder is fallbacked to CV_8U.
# Done!

# %%
# !pip install pvbm
# Out:
# Collecting pvbm
#   Downloading pvbm-3.0.0.0.tar.gz (114.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 MB 15.1 MB/s eta 0:00:00:00:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pvbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pvbm) (1.15.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from pvbm) (0.25.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from pvbm) (11.1.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (from pvbm) (5.2.0)
# Collecting onnxruntime (from pvbm)
#   Downloading onnxruntime-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from pvbm) (0.21.0+cu124)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from pvbm) (4.11.0.86)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from pvbm) (3.7.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown->pvbm) (4.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown->pvbm) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown->pvbm) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown->pvbm) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pvbm) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pvbm) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pvbm) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pvbm) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pvbm) (25.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pvbm) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pvbm) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->pvbm) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->pvbm) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->pvbm) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->pvbm) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->pvbm) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->pvbm) (2.4.1)
# Collecting coloredlogs (from onnxruntime->pvbm)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime->pvbm) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime->pvbm) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime->pvbm) (1.13.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image->pvbm) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->pvbm) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->pvbm) (2025.3.30)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->pvbm) (0.4)
# Requirement already satisfied: torch==2.6.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->pvbm) (2.6.0+cu124)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->pvbm) (4.13.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->pvbm) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->pvbm) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->pvbm) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->pvbm) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->pvbm) (12.4.127)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.6.0->torchvision->pvbm)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.6.0->torchvision->pvbm)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.6.0->torchvision->pvbm)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.6.0->torchvision->pvbm)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.6.0->torchvision->pvbm)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.6.0->torchvision->pvbm)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->pvbm) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->pvbm) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->pvbm) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.6.0->torchvision->pvbm)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->pvbm) (3.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime->pvbm) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->pvbm) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown->pvbm) (2.6)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime->pvbm)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pvbm) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pvbm) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->pvbm) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->pvbm) (2024.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->pvbm) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->pvbm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->pvbm) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->pvbm) (2025.4.26)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->pvbm) (1.7.1)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->pvbm) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.6.0->torchvision->pvbm) (3.0.2)
# Downloading onnxruntime-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 87.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 1.9 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 80.6 MB/s eta 0:00:00:00:0100:01
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.2 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 4.8 MB/s eta 0:00:00
# Building wheels for collected packages: pvbm
#   Building wheel for pvbm (setup.py) ... done
#   Created wheel for pvbm: filename=pvbm-3.0.0.0-py3-none-any.whl size=114192760 sha256=5963cd6997c6540a7da0df1338244bef59012b6637c1af8a91f8cfbf416db426
#   Stored in directory: /root/.cache/pip/wheels/79/54/73/92c28a4e4a82d98f58b0bbdeadf5191b1a44ccbd52128e0064
# Successfully built pvbm
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cublas-cu12, humanfriendly, nvidia-cusparse-cu12, nvidia-cudnn-cu12, coloredlogs, nvidia-cusolver-cu12, onnxruntime, pvbm
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.10.19
#     Uninstalling nvidia-curand-cu12-10.3.10.19:
#       Successfully uninstalled nvidia-curand-cu12-10.3.10.19
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.4.0.6
#     Uninstalling nvidia-cufft-cu12-11.4.0.6:
#       Successfully uninstalled nvidia-cufft-cu12-11.4.0.6
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.9.0.13
#     Uninstalling nvidia-cublas-cu12-12.9.0.13:
#       Successfully uninstalled nvidia-cublas-cu12-12.9.0.13
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.9.5
#     Uninstalling nvidia-cusparse-cu12-12.5.9.5:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.9.5
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.4.40
#     Uninstalling nvidia-cusolver-cu12-11.7.4.40:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.4.40
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 onnxruntime-1.22.0 pvbm-3.0.0.0

# %%
from PVBM.Datasets import PVBMDataDownloader
path_to_save_datasets = "../PVBM_datasets"
dataset_downloader = PVBMDataDownloader()
dataset_downloader.download_dataset(name="Crop_HRF", save_folder_path=path_to_save_datasets)
dataset_downloader.download_dataset(name="INSPIRE", save_folder_path=path_to_save_datasets)
dataset_downloader.download_dataset(name="UNAF", save_folder_path=path_to_save_datasets)
print("Images downloaded successfully")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1QcozuK5yDyXbBkHqkbM5bxEkTGzkPDl3
# From (redirected): https://drive.google.com/uc?id=1QcozuK5yDyXbBkHqkbM5bxEkTGzkPDl3&confirm=t&uuid=ad526f7b-e2ad-43b6-ad00-6be442b7f99a
# To: /kaggle/working/SeqNet/Crop_HRF.zip
# 100%|██████████| 42.0M/42.0M [00:00<00:00, 47.3MB/s]
# Dataset downloaded and saved to Crop_HRF.zip
# Files extracted to ../PVBM_datasets
# Deleted the zip file: Crop_HRF.zip
# Downloading...
# From (original): https://drive.google.com/uc?id=18TcmkuN_eZgM2Ph5XiX8x7_ejtKhA3qb
# From (redirected): https://drive.google.com/uc?id=18TcmkuN_eZgM2Ph5XiX8x7_ejtKhA3qb&confirm=t&uuid=a7276f0d-54d0-4fb0-be1c-12b9b6cc338d
# To: /kaggle/working/SeqNet/INSPIRE.zip
# 100%|██████████| 29.6M/29.6M [00:00<00:00, 51.4MB/s]
# Dataset downloaded and saved to INSPIRE.zip
# Files extracted to ../PVBM_datasets
# Deleted the zip file: INSPIRE.zip
# Downloading...
# From: https://drive.google.com/uc?id=1IM5qUEARNp2RFpzKmILbdgasjLuJEIcX
# To: /kaggle/working/SeqNet/UNAF.zip
# 100%|██████████| 19.7M/19.7M [00:00<00:00, 129MB/s]
# Dataset downloaded and saved to UNAF.zip
# Files extracted to ../PVBM_datasets
# Deleted the zip file: UNAF.zip
# Images downloaded successfully

# %%
import gc
import tensorflow as tf
from tensorflow.keras.layers import ReLU
from utils import crop_prediction
import numpy as np
from skimage.transform import resize
import cv2
from PIL import Image
import os

# Set up GPU memory growth
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except Exception as e:
        print(e)

def predict_single_image(image_path, output_dir, iteration=3, crop_size=128, stride_size=3):
    # Create output directories
    os.makedirs(f"{output_dir}/out_seg/", exist_ok=True)
    os.makedirs(f"{output_dir}/out_art/", exist_ok=True)
    os.makedirs(f"{output_dir}/out_vei/", exist_ok=True)
    os.makedirs(f"{output_dir}/out_final/", exist_ok=True)
    
    # Load model
    print("Loading model...")
    model = get_unet(minimum_kernel=32, do=0.1, activation=ReLU, iteration=iteration)
    model.load_weights("/kaggle/working/Final_Emer_Iteration_3_cropsize_128_epochs_200.hdf5")
    
    # Load and preprocess image
    print("Loading image...")
    filename = os.path.basename(image_path).split('.')[0]
    img = Image.open(image_path)
    image_size = img.size
    img = np.array(img) / 255.
    img = resize(img, [576, 576])
    
    # Get patches
    print("Creating patches...")
    patches_pred, new_height, new_width, _ = crop_prediction.get_test_patches(img, crop_size, stride_size)
    print(f"Total patches: {len(patches_pred)}")
    
    # Predict in small batches to save memory
    print("Predicting...")
    batch_size = 4  # Adjust this if needed
    all_preds = []
    
    for i in range(0, len(patches_pred), batch_size):
        batch = patches_pred[i:i+batch_size]
        batch_preds = model.predict(batch, verbose=0)
        all_preds.append(batch_preds)
        print(f"Processed {min(i+batch_size, len(patches_pred))}/{len(patches_pred)} patches")
        del batch
        gc.collect()
    
    # Combine predictions
    preds = []
    num_outputs = len(all_preds[0])
    for output_idx in range(num_outputs):
        output_preds = [pred[output_idx] for pred in all_preds]
        preds.append(np.concatenate(output_preds, axis=0))
    
    del all_preds, patches_pred
    gc.collect()
    
    print("Processing outputs...")
    
    # Process segmentation
    pred = preds[iteration]
    pred_patches = crop_prediction.pred_to_patches(pred, crop_size, stride_size)
    pred_imgs = crop_prediction.recompone_overlap(pred_patches, crop_size, stride_size, new_height, new_width)
    pred_seg = pred_imgs[0, :576, :576, 0]
    pred_seg = 255. * (pred_seg - np.min(pred_seg)) / (np.max(pred_seg) - np.min(pred_seg))
    cv2.imwrite(f"{output_dir}/out_seg/{filename}.png", resize(pred_seg, image_size[::-1], order=1))
    
    # Process artery
    pred = preds[2*iteration + 1]
    pred_patches = crop_prediction.pred_to_patches(pred, crop_size, stride_size)
    pred_imgs = crop_prediction.recompone_overlap(pred_patches, crop_size, stride_size, new_height, new_width)
    pred_art = pred_imgs[0, :576, :576, 0]
    pred_art = 255. * (pred_art - np.min(pred_art)) / (np.max(pred_art) - np.min(pred_art))
    cv2.imwrite(f"{output_dir}/out_art/{filename}.png", resize(pred_art, image_size[::-1], order=1))
    
    # Process vein
    pred = preds[3*iteration + 2]
    pred_patches = crop_prediction.pred_to_patches(pred, crop_size, stride_size)
    pred_imgs = crop_prediction.recompone_overlap(pred_patches, crop_size, stride_size, new_height, new_width)
    pred_vei = pred_imgs[0, :576, :576, 0]
    pred_vei = 255. * (pred_vei - np.min(pred_vei)) / (np.max(pred_vei) - np.min(pred_vei))
    cv2.imwrite(f"{output_dir}/out_vei/{filename}.png", resize(pred_vei, image_size[::-1], order=1))
    
    # Create final colored output
    pred_final = np.zeros((pred_seg.shape[0], pred_seg.shape[1], 3), dtype=np.float32)
    pred_final[(pred_art >= pred_vei), 2] = pred_seg[(pred_art >= pred_vei)]
    pred_final[(pred_art < pred_vei), 0] = pred_seg[(pred_art < pred_vei)]
    cv2.imwrite(f"{output_dir}/out_final/{filename}.png", resize(pred_final, image_size[::-1], order=1))
    
    print("Done!")

# Run prediction on single image
for i in os.listdir('/kaggle/working/PVBM_datasets/INSPIRE/images'):
    predict_single_image(
        image_path='/kaggle/working/PVBM_datasets/INSPIRE/images/'+i,  # Change this to your image path
        output_dir='/kaggle/working',
        stride_size=3  # Increase this to reduce memory usage (3 is more accurate but uses more memory)
    )
# Out:
# Loading model...
# Loading image...
# Creating patches...
# Total patches: 22801
# Predicting...
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_560']
# Received: inputs=Tensor(shape=(4, 128, 128, 3))
#   warnings.warn(msg)
# Processed 4/22801 patches
# Processed 8/22801 patches
# Processed 12/22801 patches
# Processed 16/22801 patches
# Processed 20/22801 patches
# Processed 24/22801 patches
# Processed 28/22801 patches
# Processed 32/22801 patches
# Processed 36/22801 patches
# Processed 40/22801 patches
# Processed 44/22801 patches
# Processed 48/22801 patches
# Processed 52/22801 patches
# Processed 56/22801 patches
# Processed 60/22801 patches
# Processed 64/22801 patches
# Processed 68/22801 patches
# Processed 72/22801 patches
# Processed 76/22801 patches
# Processed 80/22801 patches
# Processed 84/22801 patches
# Processed 88/22801 patches
# Processed 92/22801 patches
# Processed 96/22801 patches
# Processed 100/22801 patches
# Processed 104/22801 patches
# Processed 108/22801 patches
# Processed 112/22801 patches
# Processed 116/22801 patches
# Processed 120/22801 patches
# Processed 124/22801 patches
# Processed 128/22801 patches
# Processed 132/22801 patches
# Processed 136/22801 patches
# Processed 140/22801 patches
# Processed 144/22801 patches
# Processed 148/22801 patches
# Processed 152/22801 patches
# Processed 156/22801 patches
# Processed 160/22801 patches
# Processed 164/22801 patches
# Processed 168/22801 patches
# Processed 172/22801 patches
# Processed 176/22801 patches
# Processed 180/22801 patches
# Processed 184/22801 patches
# Processed 188/22801 patches
# Processed 192/22801 patches
# Processed 196/22801 patches
# Processed 200/22801 patches
# Processed 204/22801 patches
# Processed 208/22801 patches
# Processed 212/22801 patches
# Processed 216/22801 patches
# Processed 220/22801 patches
# Processed 224/22801 patches
# Processed 228/22801 patches
# Processed 232/22801 patches
# Processed 236/22801 patches
# Processed 240/22801 patches
# Processed 244/22801 patches
# Processed 248/22801 patches
# Processed 252/22801 patches
# Processed 256/22801 patches
# Processed 260/22801 patches
# Processed 264/22801 patches
# Processed 268/22801 patches
# Processed 272/22801 patches
# Processed 276/22801 patches
# Processed 280/22801 patches
# Processed 284/22801 patches
# Processed 288/22801 patches
# Processed 292/22801 patches
# Processed 296/22801 patches
# Processed 300/22801 patches
# Processed 304/22801 patches
# Processed 308/22801 patches
# Processed 312/22801 patches
# Processed 316/22801 patches
# Processed 320/22801 patches
# Processed 324/22801 patches
# Processed 328/22801 patches
# Processed 332/22801 patches
# Processed 336/22801 patches
# Processed 340/22801 patches
# Processed 344/22801 patches
# Processed 348/22801 patches
# Processed 352/22801 patches
# Processed 356/22801 patches
# Processed 360/22801 patches
# Processed 364/22801 patches
# Processed 368/22801 patches
# Processed 372/22801 patches
# Processed 376/22801 patches
# Processed 380/22801 patches
# Processed 384/22801 patches
# Processed 388/22801 patches
# Processed 392/22801 patches
# Processed 396/22801 patches
# Processed 400/22801 patches
# Processed 404/22801 patches
# Processed 408/22801 patches
# Processed 412/22801 patches
# Processed 416/22801 patches
# Processed 420/22801 patches
# Processed 424/22801 patches
# Processed 428/22801 patches
# Processed 432/22801 patches
# Processed 436/22801 patches
# Processed 440/22801 patches
# Processed 444/22801 patches
# Processed 448/22801 patches
# Processed 452/22801 patches
# Processed 456/22801 patches
# Processed 460/22801 patches
# Processed 464/22801 patches
# Processed 468/22801 patches
# Processed 472/22801 patches
# Processed 476/22801 patches
# Processed 480/22801 patches
# Processed 484/22801 patches
# Processed 488/22801 patches
# Processed 492/22801 patches
# Processed 496/22801 patches
# Processed 500/22801 patches
# Processed 504/22801 patches
# Processed 508/22801 patches
# Processed 512/22801 patches
# Processed 516/22801 patches
# Processed 520/22801 patches
# Processed 524/22801 patches
# Processed 528/22801 patches
# Processed 532/22801 patches
# Processed 536/22801 patches
# Processed 540/22801 patches
# Processed 544/22801 patches
# Processed 548/22801 patches
# Processed 552/22801 patches
# Processed 556/22801 patches
# Processed 560/22801 patches
# Processed 564/22801 patches
# Processed 568/22801 patches
# Processed 572/22801 patches
# Processed 576/22801 patches
# Processed 580/22801 patches
# Processed 584/22801 patches
# Processed 588/22801 patches
# Processed 592/22801 patches
# Processed 596/22801 patches
# Processed 600/22801 patches
# Processed 604/22801 patches
# Processed 608/22801 patches
# Processed 612/22801 patches
# Processed 616/22801 patches
# Processed 620/22801 patches
# Processed 624/22801 patches
# Processed 628/22801 patches
# Processed 632/22801 patches
# Processed 636/22801 patches
# Processed 640/22801 patches
# Processed 644/22801 patches
# Processed 648/22801 patches
# Processed 652/22801 patches
# Processed 656/22801 patches
# Processed 660/22801 patches
# Processed 664/22801 patches
# Processed 668/22801 patches
# Processed 672/22801 patches
# Processed 676/22801 patches
# Processed 680/22801 patches
# Processed 684/22801 patches
# Processed 688/22801 patches
# Processed 692/22801 patches
# Processed 696/22801 patches
# Processed 700/22801 patches
# Processed 704/22801 patches
# Processed 708/22801 patches
# Processed 712/22801 patches
# Processed 716/22801 patches
# Processed 720/22801 patches
# Processed 724/22801 patches
# Processed 728/22801 patches
# Processed 732/22801 patches
# Processed 736/22801 patches
# Processed 740/22801 patches
# Processed 744/22801 patches
# Processed 748/22801 patches
# Processed 752/22801 patches
# Processed 756/22801 patches
# Processed 760/22801 patches
# Processed 764/22801 patches
# Processed 768/22801 patches
# Processed 772/22801 patches
# Processed 776/22801 patches
# Processed 780/22801 patches
# Processed 784/22801 patches
# Processed 788/22801 patches
# Processed 792/22801 patches
# Processed 796/22801 patches
# Processed 800/22801 patches
# Processed 804/22801 patches
# Processed 808/22801 patches
# Processed 812/22801 patches
# Processed 816/22801 patches
# Processed 820/22801 patches
# Processed 824/22801 patches
# Processed 828/22801 patches
# Processed 832/22801 patches
# Processed 836/22801 patches
# Processed 840/22801 patches
# Processed 844/22801 patches
# Processed 848/22801 patches
# Processed 852/22801 patches
# Processed 856/22801 patches
# Processed 860/22801 patches
# Processed 864/22801 patches
# Processed 868/22801 patches
# Processed 872/22801 patches
# Processed 876/22801 patches
# Processed 880/22801 patches
# Processed 884/22801 patches
# Processed 888/22801 patches
# Processed 892/22801 patches
# Processed 896/22801 patches
# Processed 900/22801 patches
# Processed 904/22801 patches
# Processed 908/22801 patches
# Processed 912/22801 patches
# Processed 916/22801 patches
# Processed 920/22801 patches
# Processed 924/22801 patches
# Processed 928/22801 patches
# Processed 932/22801 patches
# Processed 936/22801 patches
# Processed 940/22801 patches
# Processed 944/22801 patches
# Processed 948/22801 patches
# Processed 952/22801 patches
# Processed 956/22801 patches
# Processed 960/22801 patches
# Processed 964/22801 patches
# Processed 968/22801 patches
# Processed 972/22801 patches
# Processed 976/22801 patches
# Processed 980/22801 patches
# Processed 984/22801 patches
# Processed 988/22801 patches
# Processed 992/22801 patches
# Processed 996/22801 patches
# Processed 1000/22801 patches
# Processed 1004/22801 patches
# Processed 1008/22801 patches
# Processed 1012/22801 patches
# Processed 1016/22801 patches
# Processed 1020/22801 patches
# Processed 1024/22801 patches
# Processed 1028/22801 patches
# Processed 1032/22801 patches
# Processed 1036/22801 patches
# Processed 1040/22801 patches
# Processed 1044/22801 patches
# Processed 1048/22801 patches
# Processed 1052/22801 patches
# Processed 1056/22801 patches
# Processed 1060/22801 patches
# Processed 1064/22801 patches
# Processed 1068/22801 patches
# Processed 1072/22801 patches
# Processed 1076/22801 patches
# Processed 1080/22801 patches
# Processed 1084/22801 patches
# Processed 1088/22801 patches
# Processed 1092/22801 patches
# Processed 1096/22801 patches
# Processed 1100/22801 patches
# Processed 1104/22801 patches
# Processed 1108/22801 patches
# Processed 1112/22801 patches
# Processed 1116/22801 patches
# Processed 1120/22801 patches
# Processed 1124/22801 patches
# Processed 1128/22801 patches
# Processed 1132/22801 patches
# Processed 1136/22801 patches
# Processed 1140/22801 patches
# Processed 1144/22801 patches
# Processed 1148/22801 patches
# Processed 1152/22801 patches
# Processed 1156/22801 patches
# Processed 1160/22801 patches
# Processed 1164/22801 patches
# Processed 1168/22801 patches
# Processed 1172/22801 patches
# Processed 1176/22801 patches
# Processed 1180/22801 patches
# Processed 1184/22801 patches
# Processed 1188/22801 patches
# Processed 1192/22801 patches
# Processed 1196/22801 patches
# Processed 1200/22801 patches
# Processed 1204/22801 patches
# Processed 1208/22801 patches
# Processed 1212/22801 patches
# Processed 1216/22801 patches
# Processed 1220/22801 patches
# Processed 1224/22801 patches
# Processed 1228/22801 patches
# Processed 1232/22801 patches
# Processed 1236/22801 patches
# Processed 1240/22801 patches
# Processed 1244/22801 patches
# Processed 1248/22801 patches
# Processed 1252/22801 patches
# Processed 1256/22801 patches
# Processed 1260/22801 patches
# Processed 1264/22801 patches
# Processed 1268/22801 patches
# Processed 1272/22801 patches
# Processed 1276/22801 patches
# Processed 1280/22801 patches
# Processed 1284/22801 patches
# Processed 1288/22801 patches
# Processed 1292/22801 patches
# Processed 1296/22801 patches
# Processed 1300/22801 patches
# Processed 1304/22801 patches
# Processed 1308/22801 patches
# Processed 1312/22801 patches
# Processed 1316/22801 patches
# Processed 1320/22801 patches
# Processed 1324/22801 patches
# Processed 1328/22801 patches
# Processed 1332/22801 patches
# Processed 1336/22801 patches
# Processed 1340/22801 patches
# Processed 1344/22801 patches
# Processed 1348/22801 patches
# Processed 1352/22801 patches
# Processed 1356/22801 patches
# Processed 1360/22801 patches
# Processed 1364/22801 patches
# Processed 1368/22801 patches
# Processed 1372/22801 patches
# Processed 1376/22801 patches
# Processed 1380/22801 patches
# Processed 1384/22801 patches
# Processed 1388/22801 patches
# Processed 1392/22801 patches
# Processed 1396/22801 patches
# Processed 1400/22801 patches
# Processed 1404/22801 patches
# Processed 1408/22801 patches
# Processed 1412/22801 patches
# Processed 1416/22801 patches
# Processed 1420/22801 patches
# Processed 1424/22801 patches
# Processed 1428/22801 patches
# Processed 1432/22801 patches
# Processed 1436/22801 patches
# Processed 1440/22801 patches
# Processed 1444/22801 patches
# Processed 1448/22801 patches
# Processed 1452/22801 patches
# Processed 1456/22801 patches
# Processed 1460/22801 patches
# Processed 1464/22801 patches
# Processed 1468/22801 patches
# Processed 1472/22801 patches
# Processed 1476/22801 patches
# Processed 1480/22801 patches
# Processed 1484/22801 patches
# Processed 1488/22801 patches
# Processed 1492/22801 patches
# Processed 1496/22801 patches
# Processed 1500/22801 patches
# Processed 1504/22801 patches
# Processed 1508/22801 patches
# Processed 1512/22801 patches
# Processed 1516/22801 patches
# Processed 1520/22801 patches
# Processed 1524/22801 patches
# Processed 1528/22801 patches
# Processed 1532/22801 patches
# Processed 1536/22801 patches
# Processed 1540/22801 patches
# Processed 1544/22801 patches
# Processed 1548/22801 patches
# Processed 1552/22801 patches
# Processed 1556/22801 patches
# Processed 1560/22801 patches
# Processed 1564/22801 patches
# Processed 1568/22801 patches
# Processed 1572/22801 patches
# Processed 1576/22801 patches
# Processed 1580/22801 patches
# Processed 1584/22801 patches
# Processed 1588/22801 patches
# Processed 1592/22801 patches
# Processed 1596/22801 patches
# Processed 1600/22801 patches
# Processed 1604/22801 patches
# Processed 1608/22801 patches
# Processed 1612/22801 patches
# Processed 1616/22801 patches
# Processed 1620/22801 patches
# Processed 1624/22801 patches
# Processed 1628/22801 patches
# Processed 1632/22801 patches
# Processed 1636/22801 patches
# Processed 1640/22801 patches
# Processed 1644/22801 patches
# Processed 1648/22801 patches
# Processed 1652/22801 patches
# Processed 1656/22801 patches
# Processed 1660/22801 patches
# Processed 1664/22801 patches
# Processed 1668/22801 patches
# Processed 1672/22801 patches
# Processed 1676/22801 patches
# Processed 1680/22801 patches
# Processed 1684/22801 patches
# Processed 1688/22801 patches
# Processed 1692/22801 patches
# Processed 1696/22801 patches
# Processed 1700/22801 patches
# Processed 1704/22801 patches
# Processed 1708/22801 patches
# Processed 1712/22801 patches
# Processed 1716/22801 patches
# Processed 1720/22801 patches
# Processed 1724/22801 patches
# Processed 1728/22801 patches
# Processed 1732/22801 patches
# Processed 1736/22801 patches
# Processed 1740/22801 patches
# Processed 1744/22801 patches
# Processed 1748/22801 patches
# Processed 1752/22801 patches
# Processed 1756/22801 patches
# Processed 1760/22801 patches
# Processed 1764/22801 patches
# Processed 1768/22801 patches
# Processed 1772/22801 patches
# Processed 1776/22801 patches
# Processed 1780/22801 patches
# Processed 1784/22801 patches
# Processed 1788/22801 patches
# Processed 1792/22801 patches
# Processed 1796/22801 patches
# Processed 1800/22801 patches
# Processed 1804/22801 patches
# Processed 1808/22801 patches
# Processed 1812/22801 patches
# Processed 1816/22801 patches
# Processed 1820/22801 patches
# Processed 1824/22801 patches
# Processed 1828/22801 patches
# Processed 1832/22801 patches
# Processed 1836/22801 patches
# Processed 1840/22801 patches
# Processed 1844/22801 patches
# Processed 1848/22801 patches
# Processed 1852/22801 patches
# Processed 1856/22801 patches
# Processed 1860/22801 patches
# Processed 1864/22801 patches
# Processed 1868/22801 patches
# Processed 1872/22801 patches
# Processed 1876/22801 patches
# Processed 1880/22801 patches
# Processed 1884/22801 patches
# Processed 1888/22801 patches
# Processed 1892/22801 patches
# Processed 1896/22801 patches
# Processed 1900/22801 patches
# Processed 1904/22801 patches
# Processed 1908/22801 patches
# Processed 1912/22801 patches
# Processed 1916/22801 patches
# Processed 1920/22801 patches
# Processed 1924/22801 patches
# Processed 1928/22801 patches
# Processed 1932/22801 patches
# Processed 1936/22801 patches
# Processed 1940/22801 patches
# Processed 1944/22801 patches
# Processed 1948/22801 patches
# Processed 1952/22801 patches
# Processed 1956/22801 patches
# Processed 1960/22801 patches
# Processed 1964/22801 patches
# Processed 1968/22801 patches
# Processed 1972/22801 patches
# Processed 1976/22801 patches
# Processed 1980/22801 patches
# Processed 1984/22801 patches
# Processed 1988/22801 patches
# Processed 1992/22801 patches
# Processed 1996/22801 patches
# Processed 2000/22801 patches
# Processed 2004/22801 patches
# Processed 2008/22801 patches
# Processed 2012/22801 patches
# Processed 2016/22801 patches
# Processed 2020/22801 patches
# Processed 2024/22801 patches
# Processed 2028/22801 patches
# Processed 2032/22801 patches
# Processed 2036/22801 patches
# Processed 2040/22801 patches
# Processed 2044/22801 patches
# Processed 2048/22801 patches
# Processed 2052/22801 patches
# Processed 2056/22801 patches
# Processed 2060/22801 patches
# Processed 2064/22801 patches
# Processed 2068/22801 patches
# Processed 2072/22801 patches
# Processed 2076/22801 patches
# Processed 2080/22801 patches
# Processed 2084/22801 patches
# Processed 2088/22801 patches
# Processed 2092/22801 patches
# Processed 2096/22801 patches
# Processed 2100/22801 patches
# Processed 2104/22801 patches
# Processed 2108/22801 patches
# Processed 2112/22801 patches
# Processed 2116/22801 patches
# Processed 2120/22801 patches
# Processed 2124/22801 patches
# Processed 2128/22801 patches
# Processed 2132/22801 patches
# Processed 2136/22801 patches
# Processed 2140/22801 patches
# Processed 2144/22801 patches
# Processed 2148/22801 patches
# Processed 2152/22801 patches
# Processed 2156/22801 patches
# Processed 2160/22801 patches
# Processed 2164/22801 patches
# Processed 2168/22801 patches
# Processed 2172/22801 patches
# Processed 2176/22801 patches
# Processed 2180/22801 patches
# Processed 2184/22801 patches
# Processed 2188/22801 patches
# Processed 2192/22801 patches
# Processed 2196/22801 patches
# Processed 2200/22801 patches
# Processed 2204/22801 patches
# Processed 2208/22801 patches
# Processed 2212/22801 patches
# Processed 2216/22801 patches
# Processed 2220/22801 patches
# Processed 2224/22801 patches
# Processed 2228/22801 patches
# Processed 2232/22801 patches
# Processed 2236/22801 patches
# Processed 2240/22801 patches
# Processed 2244/22801 patches
# Processed 2248/22801 patches
# Processed 2252/22801 patches
# Processed 2256/22801 patches
# Processed 2260/22801 patches
# Processed 2264/22801 patches
# Processed 2268/22801 patches
# Processed 2272/22801 patches
# Processed 2276/22801 patches
# Processed 2280/22801 patches
# Processed 2284/22801 patches
# Processed 2288/22801 patches
# Processed 2292/22801 patches
# Processed 2296/22801 patches
# Processed 2300/22801 patches
# Processed 2304/22801 patches
# Processed 2308/22801 patches
# Processed 2312/22801 patches
# Processed 2316/22801 patches
# Processed 2320/22801 patches
# Processed 2324/22801 patches
# Processed 2328/22801 patches
# Processed 2332/22801 patches
# Processed 2336/22801 patches
# Processed 2340/22801 patches
# Processed 2344/22801 patches
# Processed 2348/22801 patches
# Processed 2352/22801 patches
# Processed 2356/22801 patches
# Processed 2360/22801 patches
# Processed 2364/22801 patches
# Processed 2368/22801 patches
# Processed 2372/22801 patches
# Processed 2376/22801 patches
# Processed 2380/22801 patches
# Processed 2384/22801 patches
# Processed 2388/22801 patches
# Processed 2392/22801 patches
# Processed 2396/22801 patches
# Processed 2400/22801 patches
# Processed 2404/22801 patches
# Processed 2408/22801 patches
# Processed 2412/22801 patches
# Processed 2416/22801 patches
# Processed 2420/22801 patches
# Processed 2424/22801 patches
# Processed 2428/22801 patches
# Processed 2432/22801 patches
# Processed 2436/22801 patches
# Processed 2440/22801 patches
# Processed 2444/22801 patches
# Processed 2448/22801 patches
# Processed 2452/22801 patches
# Processed 2456/22801 patches
# Processed 2460/22801 patches
# Processed 2464/22801 patches
# Processed 2468/22801 patches
# Processed 2472/22801 patches
# Processed 2476/22801 patches
# Processed 2480/22801 patches
# Processed 2484/22801 patches
# Processed 2488/22801 patches
# Processed 2492/22801 patches
# Processed 2496/22801 patches
# Processed 2500/22801 patches
# Processed 2504/22801 patches
# Processed 2508/22801 patches
# Processed 2512/22801 patches
# Processed 2516/22801 patches
# Processed 2520/22801 patches
# Processed 2524/22801 patches
# Processed 2528/22801 patches
# Processed 2532/22801 patches
# Processed 2536/22801 patches
# Processed 2540/22801 patches
# Processed 2544/22801 patches
# Processed 2548/22801 patches
# Processed 2552/22801 patches
# Processed 2556/22801 patches
# Processed 2560/22801 patches
# Processed 2564/22801 patches
# Processed 2568/22801 patches
# Processed 2572/22801 patches
# Processed 2576/22801 patches
# Processed 2580/22801 patches
# Processed 2584/22801 patches
# Processed 2588/22801 patches
# Processed 2592/22801 patches
# Processed 2596/22801 patches
# Processed 2600/22801 patches
# Processed 2604/22801 patches
# Processed 2608/22801 patches
# Processed 2612/22801 patches
# Processed 2616/22801 patches
# Processed 2620/22801 patches
# Processed 2624/22801 patches
# Processed 2628/22801 patches
# Processed 2632/22801 patches
# Processed 2636/22801 patches
# Processed 2640/22801 patches
# Processed 2644/22801 patches
# Processed 2648/22801 patches
# Processed 2652/22801 patches
# Processed 2656/22801 patches
# Processed 2660/22801 patches
# Processed 2664/22801 patches
# Processed 2668/22801 patches
# Processed 2672/22801 patches
# Processed 2676/22801 patches
# Processed 2680/22801 patches
# Processed 2684/22801 patches
# Processed 2688/22801 patches
# Processed 2692/22801 patches
# Processed 2696/22801 patches
# Processed 2700/22801 patches
# Processed 2704/22801 patches
# Processed 2708/22801 patches
# Processed 2712/22801 patches
# Processed 2716/22801 patches
# Processed 2720/22801 patches
# Processed 2724/22801 patches
# Processed 2728/22801 patches
# Processed 2732/22801 patches
# Processed 2736/22801 patches
# Processed 2740/22801 patches
# Processed 2744/22801 patches
# Processed 2748/22801 patches
# Processed 2752/22801 patches
# Processed 2756/22801 patches
# Processed 2760/22801 patches
# Processed 2764/22801 patches
# Processed 2768/22801 patches
# Processed 2772/22801 patches
# Processed 2776/22801 patches
# Processed 2780/22801 patches
# Processed 2784/22801 patches
# Processed 2788/22801 patches
# Processed 2792/22801 patches
# Processed 2796/22801 patches
# Processed 2800/22801 patches
# Processed 2804/22801 patches
# Processed 2808/22801 patches
# Processed 2812/22801 patches
# Processed 2816/22801 patches
# Processed 2820/22801 patches
# Processed 2824/22801 patches
# Processed 2828/22801 patches
# Processed 2832/22801 patches
# Processed 2836/22801 patches
# Processed 2840/22801 patches
# Processed 2844/22801 patches
# Processed 2848/22801 patches
# Processed 2852/22801 patches
# Processed 2856/22801 patches
# Processed 2860/22801 patches
# Processed 2864/22801 patches
# Processed 2868/22801 patches
# Processed 2872/22801 patches
# Processed 2876/22801 patches
# Processed 2880/22801 patches
# Processed 2884/22801 patches
# Processed 2888/22801 patches
# Processed 2892/22801 patches
# Processed 2896/22801 patches
# Processed 2900/22801 patches
# Processed 2904/22801 patches
# Processed 2908/22801 patches
# Processed 2912/22801 patches
# Processed 2916/22801 patches
# Processed 2920/22801 patches
# Processed 2924/22801 patches
# Processed 2928/22801 patches
# Processed 2932/22801 patches
# Processed 2936/22801 patches
# Processed 2940/22801 patches
# Processed 2944/22801 patches
# Processed 2948/22801 patches
# Processed 2952/22801 patches
# Processed 2956/22801 patches
# Processed 2960/22801 patches
# Processed 2964/22801 patches
# Processed 2968/22801 patches
# Processed 2972/22801 patches
# Processed 2976/22801 patches
# Processed 2980/22801 patches
# Processed 2984/22801 patches
# Processed 2988/22801 patches
# Processed 2992/22801 patches
# Processed 2996/22801 patches
# Processed 3000/22801 patches
# Processed 3004/22801 patches
# Processed 3008/22801 patches
# Processed 3012/22801 patches
# Processed 3016/22801 patches
# Processed 3020/22801 patches
# Processed 3024/22801 patches
# Processed 3028/22801 patches
# Processed 3032/22801 patches
# Processed 3036/22801 patches
# Processed 3040/22801 patches
# Processed 3044/22801 patches
# Processed 3048/22801 patches
# Processed 3052/22801 patches
# Processed 3056/22801 patches
# Processed 3060/22801 patches
# Processed 3064/22801 patches
# Processed 3068/22801 patches
# Processed 3072/22801 patches
# Processed 3076/22801 patches
# Processed 3080/22801 patches
# Processed 3084/22801 patches
# Processed 3088/22801 patches
# Processed 3092/22801 patches
# Processed 3096/22801 patches
# Processed 3100/22801 patches
# Processed 3104/22801 patches
# Processed 3108/22801 patches
# Processed 3112/22801 patches
# Processed 3116/22801 patches
# Processed 3120/22801 patches
# Processed 3124/22801 patches
# Processed 3128/22801 patches
# Processed 3132/22801 patches
# Processed 3136/22801 patches
# Processed 3140/22801 patches
# Processed 3144/22801 patches
# Processed 3148/22801 patches
# Processed 3152/22801 patches
# Processed 3156/22801 patches
# Processed 3160/22801 patches
# Processed 3164/22801 patches
# Processed 3168/22801 patches
# Processed 3172/22801 patches
# Processed 3176/22801 patches
# Processed 3180/22801 patches
# Processed 3184/22801 patches
# Processed 3188/22801 patches
# Processed 3192/22801 patches
# Processed 3196/22801 patches
# Processed 3200/22801 patches
# Processed 3204/22801 patches
# Processed 3208/22801 patches
# Processed 3212/22801 patches
# Processed 3216/22801 patches
# Processed 3220/22801 patches
# Processed 3224/22801 patches
# Processed 3228/22801 patches
# Processed 3232/22801 patches
# Processed 3236/22801 patches
# Processed 3240/22801 patches
# Processed 3244/22801 patches
# Processed 3248/22801 patches
# Processed 3252/22801 patches
# Processed 3256/22801 patches
# Processed 3260/22801 patches
# Processed 3264/22801 patches
# Processed 3268/22801 patches
# Processed 3272/22801 patches
# Processed 3276/22801 patches
# Processed 3280/22801 patches
# Processed 3284/22801 patches
# Processed 3288/22801 patches
# Processed 3292/22801 patches
# Processed 3296/22801 patches
# Processed 3300/22801 patches
# Processed 3304/22801 patches
# Processed 3308/22801 patches
# Processed 3312/22801 patches
# Processed 3316/22801 patches
# Processed 3320/22801 patches
# Processed 3324/22801 patches
# Processed 3328/22801 patches
# Processed 3332/22801 patches
# Processed 3336/22801 patches
# Processed 3340/22801 patches
# Processed 3344/22801 patches
# Processed 3348/22801 patches
# Processed 3352/22801 patches
# Processed 3356/22801 patches
# Processed 3360/22801 patches
# Processed 3364/22801 patches
# Processed 3368/22801 patches
# Processed 3372/22801 patches
# Processed 3376/22801 patches
# Processed 3380/22801 patches
# Processed 3384/22801 patches
# Processed 3388/22801 patches
# Processed 3392/22801 patches
# Processed 3396/22801 patches
# Processed 3400/22801 patches
# Processed 3404/22801 patches
# Processed 3408/22801 patches
# Processed 3412/22801 patches
# Processed 3416/22801 patches
# Processed 3420/22801 patches
# Processed 3424/22801 patches
# Processed 3428/22801 patches
# Processed 3432/22801 patches
# Processed 3436/22801 patches
# Processed 3440/22801 patches
# Processed 3444/22801 patches
# Processed 3448/22801 patches
# Processed 3452/22801 patches
# Processed 3456/22801 patches
# Processed 3460/22801 patches
# Processed 3464/22801 patches
# Processed 3468/22801 patches
# Processed 3472/22801 patches
# Processed 3476/22801 patches
# Processed 3480/22801 patches
# Processed 3484/22801 patches
# Processed 3488/22801 patches
# Processed 3492/22801 patches
# Processed 3496/22801 patches
# Processed 3500/22801 patches
# Processed 3504/22801 patches
# Processed 3508/22801 patches
# Processed 3512/22801 patches
# Processed 3516/22801 patches
# Processed 3520/22801 patches
# Processed 3524/22801 patches
# Processed 3528/22801 patches
# Processed 3532/22801 patches
# Processed 3536/22801 patches
# Processed 3540/22801 patches
# Processed 3544/22801 patches
# Processed 3548/22801 patches
# Processed 3552/22801 patches
# Processed 3556/22801 patches
# Processed 3560/22801 patches
# Processed 3564/22801 patches
# Processed 3568/22801 patches
# Processed 3572/22801 patches
# Processed 3576/22801 patches
# Processed 3580/22801 patches
# Processed 3584/22801 patches
# Processed 3588/22801 patches
# Processed 3592/22801 patches
# Processed 3596/22801 patches
# Processed 3600/22801 patches
# Processed 3604/22801 patches
# Processed 3608/22801 patches
# Processed 3612/22801 patches
# Processed 3616/22801 patches
# Processed 3620/22801 patches
# Processed 3624/22801 patches
# Processed 3628/22801 patches
# Processed 3632/22801 patches
# Processed 3636/22801 patches
# Processed 3640/22801 patches
# Processed 3644/22801 patches
# Processed 3648/22801 patches
# Processed 3652/22801 patches
# Processed 3656/22801 patches
# Processed 3660/22801 patches
# Processed 3664/22801 patches
# Processed 3668/22801 patches
# Processed 3672/22801 patches
# Processed 3676/22801 patches
# Processed 3680/22801 patches
# Processed 3684/22801 patches
# Processed 3688/22801 patches
# Processed 3692/22801 patches
# Processed 3696/22801 patches
# Processed 3700/22801 patches
# Processed 3704/22801 patches
# Processed 3708/22801 patches
# Processed 3712/22801 patches
# Processed 3716/22801 patches
# Processed 3720/22801 patches
# Processed 3724/22801 patches
# Processed 3728/22801 patches
# Processed 3732/22801 patches
# Processed 3736/22801 patches
# Processed 3740/22801 patches
# Processed 3744/22801 patches
# Processed 3748/22801 patches
# Processed 3752/22801 patches
# Processed 3756/22801 patches
# Processed 3760/22801 patches
# Processed 3764/22801 patches
# Processed 3768/22801 patches
# Processed 3772/22801 patches
# Processed 3776/22801 patches
# Processed 3780/22801 patches
# Processed 3784/22801 patches
# Processed 3788/22801 patches
# Processed 3792/22801 patches
# Processed 3796/22801 patches
# Processed 3800/22801 patches
# Processed 3804/22801 patches
# Processed 3808/22801 patches
# Processed 3812/22801 patches
# Processed 3816/22801 patches
# Processed 3820/22801 patches
# Processed 3824/22801 patches
# Processed 3828/22801 patches
# Processed 3832/22801 patches
# Processed 3836/22801 patches
# Processed 3840/22801 patches
# Processed 3844/22801 patches
# Processed 3848/22801 patches
# Processed 3852/22801 patches
# Processed 3856/22801 patches
# Processed 3860/22801 patches
# Processed 3864/22801 patches
# Processed 3868/22801 patches
# Processed 3872/22801 patches
# Processed 3876/22801 patches
# Processed 3880/22801 patches
# Processed 3884/22801 patches
# Processed 3888/22801 patches
# Processed 3892/22801 patches
# Processed 3896/22801 patches
# Processed 3900/22801 patches
# Processed 3904/22801 patches
# Processed 3908/22801 patches
# Processed 3912/22801 patches
# Processed 3916/22801 patches
# Processed 3920/22801 patches
# Processed 3924/22801 patches
# Processed 3928/22801 patches
# Processed 3932/22801 patches
# Processed 3936/22801 patches
# Processed 3940/22801 patches
# Processed 3944/22801 patches
# Processed 3948/22801 patches
# Processed 3952/22801 patches
# Processed 3956/22801 patches
# Processed 3960/22801 patches
# Processed 3964/22801 patches
# Processed 3968/22801 patches
# Processed 3972/22801 patches
# Processed 3976/22801 patches
# Processed 3980/22801 patches
# Processed 3984/22801 patches
# Processed 3988/22801 patches
# Processed 3992/22801 patches
# Processed 3996/22801 patches
# Processed 4000/22801 patches
# Processed 4004/22801 patches
# Processed 4008/22801 patches
# Processed 4012/22801 patches
# Processed 4016/22801 patches
# Processed 4020/22801 patches
# Processed 4024/22801 patches
# Processed 4028/22801 patches
# Processed 4032/22801 patches
# Processed 4036/22801 patches
# Processed 4040/22801 patches
# Processed 4044/22801 patches
# Processed 4048/22801 patches
# Processed 4052/22801 patches
# Processed 4056/22801 patches
# Processed 4060/22801 patches
# Processed 4064/22801 patches
# Processed 4068/22801 patches
# Processed 4072/22801 patches
# Processed 4076/22801 patches
# Processed 4080/22801 patches
# Processed 4084/22801 patches
# Processed 4088/22801 patches
# Processed 4092/22801 patches
# Processed 4096/22801 patches
# Processed 4100/22801 patches
# Processed 4104/22801 patches
# Processed 4108/22801 patches
# Processed 4112/22801 patches
# Processed 4116/22801 patches
# Processed 4120/22801 patches
# Processed 4124/22801 patches
# Processed 4128/22801 patches
# Processed 4132/22801 patches
# Processed 4136/22801 patches
# Processed 4140/22801 patches
# Processed 4144/22801 patches
# Processed 4148/22801 patches
# Processed 4152/22801 patches
# Processed 4156/22801 patches
# Processed 4160/22801 patches
# Processed 4164/22801 patches
# Processed 4168/22801 patches
# Processed 4172/22801 patches
# Processed 4176/22801 patches
# Processed 4180/22801 patches
# Processed 4184/22801 patches
# Processed 4188/22801 patches
# Processed 4192/22801 patches
# Processed 4196/22801 patches
# Processed 4200/22801 patches
# Processed 4204/22801 patches
# Processed 4208/22801 patches
# Processed 4212/22801 patches
# Processed 4216/22801 patches
# Processed 4220/22801 patches
# Processed 4224/22801 patches
# Processed 4228/22801 patches
# Processed 4232/22801 patches
# Processed 4236/22801 patches
# Processed 4240/22801 patches
# Processed 4244/22801 patches
# Processed 4248/22801 patches
# Processed 4252/22801 patches
# Processed 4256/22801 patches
# Processed 4260/22801 patches
# Processed 4264/22801 patches
# Processed 4268/22801 patches
# Processed 4272/22801 patches
# Processed 4276/22801 patches
# Processed 4280/22801 patches
# Processed 4284/22801 patches
# Processed 4288/22801 patches
# Processed 4292/22801 patches
# Processed 4296/22801 patches
# Processed 4300/22801 patches
# Processed 4304/22801 patches
# Processed 4308/22801 patches
# Processed 4312/22801 patches
# Processed 4316/22801 patches
# Processed 4320/22801 patches
# Processed 4324/22801 patches
# Processed 4328/22801 patches
# Processed 4332/22801 patches
# Processed 4336/22801 patches
# Processed 4340/22801 patches
# Processed 4344/22801 patches
# Processed 4348/22801 patches
# Processed 4352/22801 patches
# Processed 4356/22801 patches
# Processed 4360/22801 patches
# Processed 4364/22801 patches
# Processed 4368/22801 patches
# Processed 4372/22801 patches
# Processed 4376/22801 patches
# Processed 4380/22801 patches
# Processed 4384/22801 patches
# Processed 4388/22801 patches
# Processed 4392/22801 patches
# Processed 4396/22801 patches
# Processed 4400/22801 patches
# Processed 4404/22801 patches
# Processed 4408/22801 patches
# Processed 4412/22801 patches
# Processed 4416/22801 patches
# Processed 4420/22801 patches
# Processed 4424/22801 patches
# Processed 4428/22801 patches
# Processed 4432/22801 patches
# Processed 4436/22801 patches
# Processed 4440/22801 patches
# Processed 4444/22801 patches
# Processed 4448/22801 patches
# Processed 4452/22801 patches
# Processed 4456/22801 patches
# Processed 4460/22801 patches
# Processed 4464/22801 patches
# Processed 4468/22801 patches
# Processed 4472/22801 patches
# Processed 4476/22801 patches
# Processed 4480/22801 patches
# Processed 4484/22801 patches
# Processed 4488/22801 patches
# Processed 4492/22801 patches
# Processed 4496/22801 patches
# Processed 4500/22801 patches
# Processed 4504/22801 patches
# Processed 4508/22801 patches
# Processed 4512/22801 patches
# Processed 4516/22801 patches
# Processed 4520/22801 patches
# Processed 4524/22801 patches
# Processed 4528/22801 patches
# Processed 4532/22801 patches
# Processed 4536/22801 patches
# Processed 4540/22801 patches
# Processed 4544/22801 patches
# Processed 4548/22801 patches
# Processed 4552/22801 patches
# Processed 4556/22801 patches
# Processed 4560/22801 patches
# Processed 4564/22801 patches
# Processed 4568/22801 patches
# Processed 4572/22801 patches
# Processed 4576/22801 patches
# Processed 4580/22801 patches
# Processed 4584/22801 patches
# Processed 4588/22801 patches
# Processed 4592/22801 patches
# Processed 4596/22801 patches
# Processed 4600/22801 patches
# Processed 4604/22801 patches
# Processed 4608/22801 patches
# Processed 4612/22801 patches
# Processed 4616/22801 patches
# Processed 4620/22801 patches
# Processed 4624/22801 patches
# Processed 4628/22801 patches
# Processed 4632/22801 patches
# Processed 4636/22801 patches
# Processed 4640/22801 patches
# Processed 4644/22801 patches
# Processed 4648/22801 patches
# Processed 4652/22801 patches
# Processed 4656/22801 patches
# Processed 4660/22801 patches
# Processed 4664/22801 patches
# Processed 4668/22801 patches
# Processed 4672/22801 patches
# Processed 4676/22801 patches
# Processed 4680/22801 patches
# Processed 4684/22801 patches
# Processed 4688/22801 patches
# Processed 4692/22801 patches
# Processed 4696/22801 patches
# Processed 4700/22801 patches
# Processed 4704/22801 patches
# Processed 4708/22801 patches
# Processed 4712/22801 patches
# Processed 4716/22801 patches
# Processed 4720/22801 patches
# Processed 4724/22801 patches
# Processed 4728/22801 patches
# Processed 4732/22801 patches
# Processed 4736/22801 patches
# Processed 4740/22801 patches
# Processed 4744/22801 patches
# Processed 4748/22801 patches
# Processed 4752/22801 patches
# Processed 4756/22801 patches
# Processed 4760/22801 patches
# Processed 4764/22801 patches
# Processed 4768/22801 patches
# Processed 4772/22801 patches
# Processed 4776/22801 patches
# Processed 4780/22801 patches
# Processed 4784/22801 patches
# Processed 4788/22801 patches
# Processed 4792/22801 patches
# Processed 4796/22801 patches
# Processed 4800/22801 patches
# Processed 4804/22801 patches
# Processed 4808/22801 patches
# Processed 4812/22801 patches
# Processed 4816/22801 patches
# Processed 4820/22801 patches
# Processed 4824/22801 patches
# Processed 4828/22801 patches
# Processed 4832/22801 patches
# Processed 4836/22801 patches
# Processed 4840/22801 patches
# Processed 4844/22801 patches
# Processed 4848/22801 patches
# Processed 4852/22801 patches
# Processed 4856/22801 patches
# Processed 4860/22801 patches
# Processed 4864/22801 patches
# Processed 4868/22801 patches
# Processed 4872/22801 patches
# Processed 4876/22801 patches
# Processed 4880/22801 patches
# Processed 4884/22801 patches
# Processed 4888/22801 patches
# Processed 4892/22801 patches
# Processed 4896/22801 patches
# Processed 4900/22801 patches
# Processed 4904/22801 patches
# Processed 4908/22801 patches
# Processed 4912/22801 patches
# Processed 4916/22801 patches
# Processed 4920/22801 patches
# Processed 4924/22801 patches
# Processed 4928/22801 patches
# Processed 4932/22801 patches
# Processed 4936/22801 patches
# Processed 4940/22801 patches
# Processed 4944/22801 patches
# Processed 4948/22801 patches
# Processed 4952/22801 patches
# Processed 4956/22801 patches
# Processed 4960/22801 patches
# Processed 4964/22801 patches
# Processed 4968/22801 patches
# Processed 4972/22801 patches
# Processed 4976/22801 patches
# Processed 4980/22801 patches
# Processed 4984/22801 patches
# Processed 4988/22801 patches
# Processed 4992/22801 patches
# Processed 4996/22801 patches
# Processed 5000/22801 patches
# Processed 5004/22801 patches
# Processed 5008/22801 patches
# Processed 5012/22801 patches
# Processed 5016/22801 patches
# Processed 5020/22801 patches
# Processed 5024/22801 patches
# Processed 5028/22801 patches
# Processed 5032/22801 patches
# Processed 5036/22801 patches
# Processed 5040/22801 patches
# Processed 5044/22801 patches
# Processed 5048/22801 patches
# Processed 5052/22801 patches
# Processed 5056/22801 patches
# Processed 5060/22801 patches
# Processed 5064/22801 patches
# Processed 5068/22801 patches
# Processed 5072/22801 patches
# Processed 5076/22801 patches
# Processed 5080/22801 patches
# Processed 5084/22801 patches
# Processed 5088/22801 patches
# Processed 5092/22801 patches
# Processed 5096/22801 patches
# Processed 5100/22801 patches
# Processed 5104/22801 patches
# Processed 5108/22801 patches
# Processed 5112/22801 patches
# Processed 5116/22801 patches
# Processed 5120/22801 patches
# Processed 5124/22801 patches
# Processed 5128/22801 patches
# Processed 5132/22801 patches
# Processed 5136/22801 patches
# Processed 5140/22801 patches
# Processed 5144/22801 patches
# Processed 5148/22801 patches
# Processed 5152/22801 patches
# Processed 5156/22801 patches
# Processed 5160/22801 patches
# Processed 5164/22801 patches
# Processed 5168/22801 patches
# Processed 5172/22801 patches
# Processed 5176/22801 patches
# Processed 5180/22801 patches
# Processed 5184/22801 patches
# Processed 5188/22801 patches
# Processed 5192/22801 patches
# Processed 5196/22801 patches
# Processed 5200/22801 patches
# Processed 5204/22801 patches
# Processed 5208/22801 patches
# Processed 5212/22801 patches
# Processed 5216/22801 patches
# Processed 5220/22801 patches
# Processed 5224/22801 patches
# Processed 5228/22801 patches
# Processed 5232/22801 patches
# Processed 5236/22801 patches
# Processed 5240/22801 patches
# Processed 5244/22801 patches
# Processed 5248/22801 patches
# Processed 5252/22801 patches
# Processed 5256/22801 patches
# Processed 5260/22801 patches
# Processed 5264/22801 patches
# Processed 5268/22801 patches
# Processed 5272/22801 patches
# Processed 5276/22801 patches
# Processed 5280/22801 patches
# Processed 5284/22801 patches
# Processed 5288/22801 patches
# Processed 5292/22801 patches
# Processed 5296/22801 patches
# Processed 5300/22801 patches
# Processed 5304/22801 patches
# Processed 5308/22801 patches
# Processed 5312/22801 patches
# Processed 5316/22801 patches
# Processed 5320/22801 patches
# Processed 5324/22801 patches
# Processed 5328/22801 patches
# Processed 5332/22801 patches
# Processed 5336/22801 patches
# Processed 5340/22801 patches
# Processed 5344/22801 patches
# Processed 5348/22801 patches
# Processed 5352/22801 patches
# Processed 5356/22801 patches
# Processed 5360/22801 patches
# Processed 5364/22801 patches
# Processed 5368/22801 patches
# Processed 5372/22801 patches
# Processed 5376/22801 patches
# Processed 5380/22801 patches
# Processed 5384/22801 patches
# Processed 5388/22801 patches
# Processed 5392/22801 patches
# Processed 5396/22801 patches
# Processed 5400/22801 patches
# Processed 5404/22801 patches
# Processed 5408/22801 patches
# Processed 5412/22801 patches
# Processed 5416/22801 patches
# Processed 5420/22801 patches
# Processed 5424/22801 patches
# Processed 5428/22801 patches
# Processed 5432/22801 patches
# Processed 5436/22801 patches
# Processed 5440/22801 patches
# Processed 5444/22801 patches
# Processed 5448/22801 patches
# Processed 5452/22801 patches
# Processed 5456/22801 patches
# Processed 5460/22801 patches
# Processed 5464/22801 patches
# Processed 5468/22801 patches
# Processed 5472/22801 patches
# Processed 5476/22801 patches
# Processed 5480/22801 patches
# Processed 5484/22801 patches
# Processed 5488/22801 patches
# Processed 5492/22801 patches
# Processed 5496/22801 patches
# Processed 5500/22801 patches
# Processed 5504/22801 patches
# Processed 5508/22801 patches
# Processed 5512/22801 patches
# Processed 5516/22801 patches
# Processed 5520/22801 patches
# Processed 5524/22801 patches
# Processed 5528/22801 patches
# Processed 5532/22801 patches
# Processed 5536/22801 patches
# Processed 5540/22801 patches
# Processed 5544/22801 patches
# Processed 5548/22801 patches
# Processed 5552/22801 patches
# Processed 5556/22801 patches
# Processed 5560/22801 patches
# Processed 5564/22801 patches
# Processed 5568/22801 patches
# Processed 5572/22801 patches
# Processed 5576/22801 patches
# Processed 5580/22801 patches
# Processed 5584/22801 patches
# Processed 5588/22801 patches
# Processed 5592/22801 patches
# Processed 5596/22801 patches
# Processed 5600/22801 patches
# Processed 5604/22801 patches
# Processed 5608/22801 patches
# Processed 5612/22801 patches
# Processed 5616/22801 patches
# Processed 5620/22801 patches
# Processed 5624/22801 patches
# Processed 5628/22801 patches
# Processed 5632/22801 patches
# Processed 5636/22801 patches
# Processed 5640/22801 patches
# Processed 5644/22801 patches
# Processed 5648/22801 patches
# Processed 5652/22801 patches
# Processed 5656/22801 patches
# Processed 5660/22801 patches
# Processed 5664/22801 patches
# Processed 5668/22801 patches
# Processed 5672/22801 patches
# Processed 5676/22801 patches
# Processed 5680/22801 patches
# Processed 5684/22801 patches
# Processed 5688/22801 patches
# Processed 5692/22801 patches
# Processed 5696/22801 patches
# Processed 5700/22801 patches
# Processed 5704/22801 patches
# Processed 5708/22801 patches
# Processed 5712/22801 patches
# Processed 5716/22801 patches
# Processed 5720/22801 patches
# Processed 5724/22801 patches
# Processed 5728/22801 patches
# Processed 5732/22801 patches
# Processed 5736/22801 patches
# Processed 5740/22801 patches
# Processed 5744/22801 patches
# Processed 5748/22801 patches
# Processed 5752/22801 patches
# Processed 5756/22801 patches
# Processed 5760/22801 patches
# Processed 5764/22801 patches
# Processed 5768/22801 patches
# Processed 5772/22801 patches
# Processed 5776/22801 patches
# Processed 5780/22801 patches
# Processed 5784/22801 patches
# Processed 5788/22801 patches
# Processed 5792/22801 patches
# Processed 5796/22801 patches
# Processed 5800/22801 patches
# Processed 5804/22801 patches
# Processed 5808/22801 patches
# Processed 5812/22801 patches
# Processed 5816/22801 patches
# Processed 5820/22801 patches
# Processed 5824/22801 patches
# Processed 5828/22801 patches
# Processed 5832/22801 patches
# Processed 5836/22801 patches
# Processed 5840/22801 patches
# Processed 5844/22801 patches
# Processed 5848/22801 patches
# Processed 5852/22801 patches
# Processed 5856/22801 patches
# Processed 5860/22801 patches
# Processed 5864/22801 patches
# Processed 5868/22801 patches
# Processed 5872/22801 patches
# Processed 5876/22801 patches
# Processed 5880/22801 patches
# Processed 5884/22801 patches
# Processed 5888/22801 patches
# Processed 5892/22801 patches
# Processed 5896/22801 patches
# Processed 5900/22801 patches
# Processed 5904/22801 patches
# Processed 5908/22801 patches
# Processed 5912/22801 patches
# Processed 5916/22801 patches
# Processed 5920/22801 patches
# Processed 5924/22801 patches
# Processed 5928/22801 patches
# Processed 5932/22801 patches
# Processed 5936/22801 patches
# Processed 5940/22801 patches
# Processed 5944/22801 patches
# Processed 5948/22801 patches
# Processed 5952/22801 patches
# Processed 5956/22801 patches
# Processed 5960/22801 patches
# Processed 5964/22801 patches
# Processed 5968/22801 patches
# Processed 5972/22801 patches
# Processed 5976/22801 patches
# Processed 5980/22801 patches
# Processed 5984/22801 patches
# Processed 5988/22801 patches
# Processed 5992/22801 patches
# Processed 5996/22801 patches
# Processed 6000/22801 patches
# Processed 6004/22801 patches
# Processed 6008/22801 patches
# Processed 6012/22801 patches
# Processed 6016/22801 patches
# Processed 6020/22801 patches
# Processed 6024/22801 patches
# Processed 6028/22801 patches
# Processed 6032/22801 patches
# Processed 6036/22801 patches
# Processed 6040/22801 patches
# Processed 6044/22801 patches
# Processed 6048/22801 patches
# Processed 6052/22801 patches
# Processed 6056/22801 patches
# Processed 6060/22801 patches
# Processed 6064/22801 patches
# Processed 6068/22801 patches
# Processed 6072/22801 patches
# Processed 6076/22801 patches
# Processed 6080/22801 patches
# Processed 6084/22801 patches
# Processed 6088/22801 patches
# Processed 6092/22801 patches
# Processed 6096/22801 patches
# Processed 6100/22801 patches
# Processed 6104/22801 patches
# Processed 6108/22801 patches
# Processed 6112/22801 patches
# Processed 6116/22801 patches
# Processed 6120/22801 patches
# Processed 6124/22801 patches
# Processed 6128/22801 patches
# Processed 6132/22801 patches
# Processed 6136/22801 patches
# Processed 6140/22801 patches
# Processed 6144/22801 patches
# Processed 6148/22801 patches
# Processed 6152/22801 patches
# Processed 6156/22801 patches
# Processed 6160/22801 patches
# Processed 6164/22801 patches
# Processed 6168/22801 patches
# Processed 6172/22801 patches
# Processed 6176/22801 patches
# Processed 6180/22801 patches
# Processed 6184/22801 patches
# Processed 6188/22801 patches
# Processed 6192/22801 patches
# Processed 6196/22801 patches
# Processed 6200/22801 patches
# Processed 6204/22801 patches
# Processed 6208/22801 patches
# Processed 6212/22801 patches
# Processed 6216/22801 patches
# Processed 6220/22801 patches
# Processed 6224/22801 patches
# Processed 6228/22801 patches
# Processed 6232/22801 patches
# Processed 6236/22801 patches
# Processed 6240/22801 patches
# Processed 6244/22801 patches
# Processed 6248/22801 patches
# Processed 6252/22801 patches
# Processed 6256/22801 patches
# Processed 6260/22801 patches
# Processed 6264/22801 patches
# Processed 6268/22801 patches
# Processed 6272/22801 patches
# Processed 6276/22801 patches
# Processed 6280/22801 patches
# Processed 6284/22801 patches
# Processed 6288/22801 patches
# Processed 6292/22801 patches
# Processed 6296/22801 patches
# Processed 6300/22801 patches
# Processed 6304/22801 patches
# Processed 6308/22801 patches
# Processed 6312/22801 patches
# Processed 6316/22801 patches
# Processed 6320/22801 patches
# Processed 6324/22801 patches
# Processed 6328/22801 patches
# Processed 6332/22801 patches
# Processed 6336/22801 patches
# Processed 6340/22801 patches
# Processed 6344/22801 patches
# Processed 6348/22801 patches
# Processed 6352/22801 patches
# Processed 6356/22801 patches
# Processed 6360/22801 patches
# Processed 6364/22801 patches
# Processed 6368/22801 patches
# Processed 6372/22801 patches
# Processed 6376/22801 patches
# Processed 6380/22801 patches
# Processed 6384/22801 patches
# Processed 6388/22801 patches
# Processed 6392/22801 patches
# Processed 6396/22801 patches
# Processed 6400/22801 patches
# Processed 6404/22801 patches
# Processed 6408/22801 patches
# Processed 6412/22801 patches
# Processed 6416/22801 patches
# Processed 6420/22801 patches
# Processed 6424/22801 patches
# Processed 6428/22801 patches
# Processed 6432/22801 patches
# Processed 6436/22801 patches
# Processed 6440/22801 patches
# Processed 6444/22801 patches
# Processed 6448/22801 patches
# Processed 6452/22801 patches
# Processed 6456/22801 patches
# Processed 6460/22801 patches
# Processed 6464/22801 patches
# Processed 6468/22801 patches
# Processed 6472/22801 patches
# Processed 6476/22801 patches
# Processed 6480/22801 patches
# Processed 6484/22801 patches
# Processed 6488/22801 patches
# Processed 6492/22801 patches
# Processed 6496/22801 patches
# Processed 6500/22801 patches
# Processed 6504/22801 patches
# Processed 6508/22801 patches
# Processed 6512/22801 patches
# Processed 6516/22801 patches
# Processed 6520/22801 patches
# Processed 6524/22801 patches
# Processed 6528/22801 patches
# Processed 6532/22801 patches
# Processed 6536/22801 patches
# Processed 6540/22801 patches
# Processed 6544/22801 patches
# Processed 6548/22801 patches
# Processed 6552/22801 patches
# Processed 6556/22801 patches
# Processed 6560/22801 patches
# Processed 6564/22801 patches
# Processed 6568/22801 patches
# Processed 6572/22801 patches
# Processed 6576/22801 patches
# Processed 6580/22801 patches
# Processed 6584/22801 patches
# Processed 6588/22801 patches
# Processed 6592/22801 patches
# Processed 6596/22801 patches
# Processed 6600/22801 patches
# Processed 6604/22801 patches
# Processed 6608/22801 patches
# ...
# Processed 20712/22801 patches
# Processed 20716/22801 patches
# Processed 20720/22801 patches
# Processed 20724/22801 patches
# Processed 20728/22801 patches
# Processed 20732/22801 patches
# Processed 20736/22801 patches
# Processed 20740/22801 patches
# Processed 20744/22801 patches
# Processed 20748/22801 patches
# Processed 20752/22801 patches
# Processed 20756/22801 patches
# Processed 20760/22801 patches
# Processed 20764/22801 patches
# Processed 20768/22801 patches
# Processed 20772/22801 patches
# Processed 20776/22801 patches
# Processed 20780/22801 patches
# Processed 20784/22801 patches
# Processed 20788/22801 patches
# Processed 20792/22801 patches
# Processed 20796/22801 patches
# Processed 20800/22801 patches
# Processed 20804/22801 patches
# Processed 20808/22801 patches
# Processed 20812/22801 patches
# Processed 20816/22801 patches
# Processed 20820/22801 patches
# Processed 20824/22801 patches
# Processed 20828/22801 patches
# Processed 20832/22801 patches
# Processed 20836/22801 patches
# Processed 20840/22801 patches
# Processed 20844/22801 patches
# Processed 20848/22801 patches
# Processed 20852/22801 patches
# Processed 20856/22801 patches
# Processed 20860/22801 patches
# Processed 20864/22801 patches
# Processed 20868/22801 patches
# Processed 20872/22801 patches
# Processed 20876/22801 patches
# Processed 20880/22801 patches
# Processed 20884/22801 patches
# Processed 20888/22801 patches
# Processed 20892/22801 patches
# Processed 20896/22801 patches
# Processed 20900/22801 patches
# Processed 20904/22801 patches
# Processed 20908/22801 patches
# Processed 20912/22801 patches
# Processed 20916/22801 patches
# Processed 20920/22801 patches
# Processed 20924/22801 patches
# Processed 20928/22801 patches
# Processed 20932/22801 patches
# Processed 20936/22801 patches
# Processed 20940/22801 patches
# Processed 20944/22801 patches
# Processed 20948/22801 patches
# Processed 20952/22801 patches
# Processed 20956/22801 patches
# Processed 20960/22801 patches
# Processed 20964/22801 patches
# Processed 20968/22801 patches
# Processed 20972/22801 patches
# Processed 20976/22801 patches
# Processed 20980/22801 patches
# Processed 20984/22801 patches
# Processed 20988/22801 patches
# Processed 20992/22801 patches
# Processed 20996/22801 patches
# Processed 21000/22801 patches
# Processed 21004/22801 patches
# Processed 21008/22801 patches
# Processed 21012/22801 patches
# Processed 21016/22801 patches
# Processed 21020/22801 patches
# Processed 21024/22801 patches
# Processed 21028/22801 patches
# Processed 21032/22801 patches
# Processed 21036/22801 patches
# Processed 21040/22801 patches
# Processed 21044/22801 patches
# Processed 21048/22801 patches
# Processed 21052/22801 patches
# Processed 21056/22801 patches
# Processed 21060/22801 patches
# Processed 21064/22801 patches
# Processed 21068/22801 patches
# Processed 21072/22801 patches
# Processed 21076/22801 patches
# Processed 21080/22801 patches
# Processed 21084/22801 patches
# Processed 21088/22801 patches
# Processed 21092/22801 patches
# Processed 21096/22801 patches
# Processed 21100/22801 patches
# Processed 21104/22801 patches
# Processed 21108/22801 patches
# Processed 21112/22801 patches
# Processed 21116/22801 patches
# Processed 21120/22801 patches
# Processed 21124/22801 patches
# Processed 21128/22801 patches
# Processed 21132/22801 patches
# Processed 21136/22801 patches
# Processed 21140/22801 patches
# Processed 21144/22801 patches
# Processed 21148/22801 patches
# Processed 21152/22801 patches
# Processed 21156/22801 patches
# Processed 21160/22801 patches
# Processed 21164/22801 patches
# Processed 21168/22801 patches
# Processed 21172/22801 patches
# Processed 21176/22801 patches
# Processed 21180/22801 patches
# Processed 21184/22801 patches
# Processed 21188/22801 patches
# Processed 21192/22801 patches
# Processed 21196/22801 patches
# Processed 21200/22801 patches
# Processed 21204/22801 patches
# Processed 21208/22801 patches
# Processed 21212/22801 patches
# Processed 21216/22801 patches
# Processed 21220/22801 patches
# Processed 21224/22801 patches
# Processed 21228/22801 patches
# Processed 21232/22801 patches
# Processed 21236/22801 patches
# Processed 21240/22801 patches
# Processed 21244/22801 patches
# Processed 21248/22801 patches
# Processed 21252/22801 patches
# Processed 21256/22801 patches
# Processed 21260/22801 patches
# Processed 21264/22801 patches
# Processed 21268/22801 patches
# Processed 21272/22801 patches
# Processed 21276/22801 patches
# Processed 21280/22801 patches
# Processed 21284/22801 patches
# Processed 21288/22801 patches
# Processed 21292/22801 patches
# Processed 21296/22801 patches
# Processed 21300/22801 patches
# Processed 21304/22801 patches
# Processed 21308/22801 patches
# Processed 21312/22801 patches
# Processed 21316/22801 patches
# Processed 21320/22801 patches
# Processed 21324/22801 patches
# Processed 21328/22801 patches
# Processed 21332/22801 patches
# Processed 21336/22801 patches
# Processed 21340/22801 patches
# Processed 21344/22801 patches
# Processed 21348/22801 patches
# Processed 21352/22801 patches
# Processed 21356/22801 patches
# Processed 21360/22801 patches
# Processed 21364/22801 patches
# Processed 21368/22801 patches
# Processed 21372/22801 patches
# Processed 21376/22801 patches
# Processed 21380/22801 patches
# Processed 21384/22801 patches
# Processed 21388/22801 patches
# Processed 21392/22801 patches
# Processed 21396/22801 patches
# Processed 21400/22801 patches
# Processed 21404/22801 patches
# Processed 21408/22801 patches
# Processed 21412/22801 patches
# Processed 21416/22801 patches
# Processed 21420/22801 patches
# Processed 21424/22801 patches
# Processed 21428/22801 patches
# Processed 21432/22801 patches
# Processed 21436/22801 patches
# Processed 21440/22801 patches
# Processed 21444/22801 patches
# Processed 21448/22801 patches
# Processed 21452/22801 patches
# Processed 21456/22801 patches
# Processed 21460/22801 patches
# Processed 21464/22801 patches
# Processed 21468/22801 patches
# Processed 21472/22801 patches
# Processed 21476/22801 patches
# Processed 21480/22801 patches
# Processed 21484/22801 patches
# Processed 21488/22801 patches
# Processed 21492/22801 patches
# Processed 21496/22801 patches
# Processed 21500/22801 patches
# Processed 21504/22801 patches
# Processed 21508/22801 patches
# Processed 21512/22801 patches
# Processed 21516/22801 patches
# Processed 21520/22801 patches
# Processed 21524/22801 patches
# Processed 21528/22801 patches
# Processed 21532/22801 patches
# Processed 21536/22801 patches
# Processed 21540/22801 patches
# Processed 21544/22801 patches
# Processed 21548/22801 patches
# Processed 21552/22801 patches
# Processed 21556/22801 patches
# Processed 21560/22801 patches
# Processed 21564/22801 patches
# Processed 21568/22801 patches
# Processed 21572/22801 patches
# Processed 21576/22801 patches
# Processed 21580/22801 patches
# Processed 21584/22801 patches
# Processed 21588/22801 patches
# Processed 21592/22801 patches
# Processed 21596/22801 patches
# Processed 21600/22801 patches
# Processed 21604/22801 patches
# Processed 21608/22801 patches
# Processed 21612/22801 patches
# Processed 21616/22801 patches
# Processed 21620/22801 patches
# Processed 21624/22801 patches
# Processed 21628/22801 patches
# Processed 21632/22801 patches
# Processed 21636/22801 patches
# Processed 21640/22801 patches
# Processed 21644/22801 patches
# Processed 21648/22801 patches
# Processed 21652/22801 patches
# Processed 21656/22801 patches
# Processed 21660/22801 patches
# Processed 21664/22801 patches
# Processed 21668/22801 patches
# Processed 21672/22801 patches
# Processed 21676/22801 patches
# Processed 21680/22801 patches
# Processed 21684/22801 patches
# Processed 21688/22801 patches
# Processed 21692/22801 patches
# Processed 21696/22801 patches
# Processed 21700/22801 patches
# Processed 21704/22801 patches
# Processed 21708/22801 patches
# Processed 21712/22801 patches
# Processed 21716/22801 patches
# Processed 21720/22801 patches
# Processed 21724/22801 patches
# Processed 21728/22801 patches
# Processed 21732/22801 patches
# Processed 21736/22801 patches
# Processed 21740/22801 patches
# Processed 21744/22801 patches
# Processed 21748/22801 patches
# Processed 21752/22801 patches
# Processed 21756/22801 patches
# Processed 21760/22801 patches
# Processed 21764/22801 patches
# Processed 21768/22801 patches
# Processed 21772/22801 patches
# Processed 21776/22801 patches
# Processed 21780/22801 patches
# Processed 21784/22801 patches
# Processed 21788/22801 patches
# Processed 21792/22801 patches
# Processed 21796/22801 patches
# Processed 21800/22801 patches
# Processed 21804/22801 patches
# Processed 21808/22801 patches
# Processed 21812/22801 patches
# Processed 21816/22801 patches
# Processed 21820/22801 patches
# Processed 21824/22801 patches
# Processed 21828/22801 patches
# Processed 21832/22801 patches
# Processed 21836/22801 patches
# Processed 21840/22801 patches
# Processed 21844/22801 patches
# Processed 21848/22801 patches
# Processed 21852/22801 patches
# Processed 21856/22801 patches
# Processed 21860/22801 patches
# Processed 21864/22801 patches
# Processed 21868/22801 patches
# Processed 21872/22801 patches
# Processed 21876/22801 patches
# Processed 21880/22801 patches
# Processed 21884/22801 patches
# Processed 21888/22801 patches
# Processed 21892/22801 patches
# Processed 21896/22801 patches
# Processed 21900/22801 patches
# Processed 21904/22801 patches
# Processed 21908/22801 patches
# Processed 21912/22801 patches
# Processed 21916/22801 patches
# Processed 21920/22801 patches
# Processed 21924/22801 patches
# Processed 21928/22801 patches
# Processed 21932/22801 patches
# Processed 21936/22801 patches
# Processed 21940/22801 patches
# Processed 21944/22801 patches
# Processed 21948/22801 patches
# Processed 21952/22801 patches
# Processed 21956/22801 patches
# Processed 21960/22801 patches
# Processed 21964/22801 patches
# Processed 21968/22801 patches
# Processed 21972/22801 patches
# Processed 21976/22801 patches
# Processed 21980/22801 patches
# Processed 21984/22801 patches
# Processed 21988/22801 patches
# Processed 21992/22801 patches
# Processed 21996/22801 patches
# Processed 22000/22801 patches
# Processed 22004/22801 patches
# Processed 22008/22801 patches
# Processed 22012/22801 patches
# Processed 22016/22801 patches
# Processed 22020/22801 patches
# Processed 22024/22801 patches
# Processed 22028/22801 patches
# Processed 22032/22801 patches
# Processed 22036/22801 patches
# Processed 22040/22801 patches
# Processed 22044/22801 patches
# Processed 22048/22801 patches
# Processed 22052/22801 patches
# Processed 22056/22801 patches
# Processed 22060/22801 patches
# Processed 22064/22801 patches
# Processed 22068/22801 patches
# Processed 22072/22801 patches
# Processed 22076/22801 patches
# Processed 22080/22801 patches
# Processed 22084/22801 patches
# Processed 22088/22801 patches
# Processed 22092/22801 patches
# Processed 22096/22801 patches
# Processed 22100/22801 patches
# Processed 22104/22801 patches
# Processed 22108/22801 patches
# Processed 22112/22801 patches
# Processed 22116/22801 patches
# Processed 22120/22801 patches
# Processed 22124/22801 patches
# Processed 22128/22801 patches
# Processed 22132/22801 patches
# Processed 22136/22801 patches
# Processed 22140/22801 patches
# Processed 22144/22801 patches
# Processed 22148/22801 patches
# Processed 22152/22801 patches
# Processed 22156/22801 patches
# Processed 22160/22801 patches
# Processed 22164/22801 patches
# Processed 22168/22801 patches
# Processed 22172/22801 patches
# Processed 22176/22801 patches
# Processed 22180/22801 patches
# Processed 22184/22801 patches
# Processed 22188/22801 patches
# Processed 22192/22801 patches
# Processed 22196/22801 patches
# Processed 22200/22801 patches
# Processed 22204/22801 patches
# Processed 22208/22801 patches
# Processed 22212/22801 patches
# Processed 22216/22801 patches
# Processed 22220/22801 patches
# Processed 22224/22801 patches
# Processed 22228/22801 patches
# Processed 22232/22801 patches
# Processed 22236/22801 patches
# Processed 22240/22801 patches
# Processed 22244/22801 patches
# Processed 22248/22801 patches
# Processed 22252/22801 patches
# Processed 22256/22801 patches
# Processed 22260/22801 patches
# Processed 22264/22801 patches
# Processed 22268/22801 patches
# Processed 22272/22801 patches
# Processed 22276/22801 patches
# Processed 22280/22801 patches
# Processed 22284/22801 patches
# Processed 22288/22801 patches
# Processed 22292/22801 patches
# Processed 22296/22801 patches
# Processed 22300/22801 patches
# Processed 22304/22801 patches
# Processed 22308/22801 patches
# Processed 22312/22801 patches
# Processed 22316/22801 patches
# Processed 22320/22801 patches
# Processed 22324/22801 patches
# Processed 22328/22801 patches
# Processed 22332/22801 patches
# Processed 22336/22801 patches
# Processed 22340/22801 patches
# Processed 22344/22801 patches
# Processed 22348/22801 patches
# Processed 22352/22801 patches
# Processed 22356/22801 patches
# Processed 22360/22801 patches
# Processed 22364/22801 patches
# Processed 22368/22801 patches
# Processed 22372/22801 patches
# Processed 22376/22801 patches
# Processed 22380/22801 patches
# Processed 22384/22801 patches
# Processed 22388/22801 patches
# Processed 22392/22801 patches
# Processed 22396/22801 patches
# Processed 22400/22801 patches
# Processed 22404/22801 patches
# Processed 22408/22801 patches
# Processed 22412/22801 patches
# Processed 22416/22801 patches
# Processed 22420/22801 patches
# Processed 22424/22801 patches
# Processed 22428/22801 patches
# Processed 22432/22801 patches
# Processed 22436/22801 patches
# Processed 22440/22801 patches
# Processed 22444/22801 patches
# Processed 22448/22801 patches
# Processed 22452/22801 patches
# Processed 22456/22801 patches
# Processed 22460/22801 patches
# Processed 22464/22801 patches
# Processed 22468/22801 patches
# Processed 22472/22801 patches
# Processed 22476/22801 patches
# Processed 22480/22801 patches
# Processed 22484/22801 patches
# Processed 22488/22801 patches
# Processed 22492/22801 patches
# Processed 22496/22801 patches
# Processed 22500/22801 patches
# Processed 22504/22801 patches
# Processed 22508/22801 patches
# Processed 22512/22801 patches
# Processed 22516/22801 patches
# Processed 22520/22801 patches
# Processed 22524/22801 patches
# Processed 22528/22801 patches
# Processed 22532/22801 patches
# Processed 22536/22801 patches
# Processed 22540/22801 patches
# Processed 22544/22801 patches
# Processed 22548/22801 patches
# Processed 22552/22801 patches
# Processed 22556/22801 patches
# Processed 22560/22801 patches
# Processed 22564/22801 patches
# Processed 22568/22801 patches
# Processed 22572/22801 patches
# Processed 22576/22801 patches
# Processed 22580/22801 patches
# Processed 22584/22801 patches
# Processed 22588/22801 patches
# Processed 22592/22801 patches
# Processed 22596/22801 patches
# Processed 22600/22801 patches
# Processed 22604/22801 patches
# Processed 22608/22801 patches
# Processed 22612/22801 patches
# Processed 22616/22801 patches
# Processed 22620/22801 patches
# Processed 22624/22801 patches
# Processed 22628/22801 patches
# Processed 22632/22801 patches
# Processed 22636/22801 patches
# Processed 22640/22801 patches
# Processed 22644/22801 patches
# Processed 22648/22801 patches
# Processed 22652/22801 patches
# Processed 22656/22801 patches
# Processed 22660/22801 patches
# Processed 22664/22801 patches
# Processed 22668/22801 patches
# Processed 22672/22801 patches
# Processed 22676/22801 patches
# Processed 22680/22801 patches
# Processed 22684/22801 patches
# Processed 22688/22801 patches
# Processed 22692/22801 patches
# Processed 22696/22801 patches
# Processed 22700/22801 patches
# Processed 22704/22801 patches
# Processed 22708/22801 patches
# Processed 22712/22801 patches
# Processed 22716/22801 patches
# Processed 22720/22801 patches
# Processed 22724/22801 patches
# Processed 22728/22801 patches
# Processed 22732/22801 patches
# Processed 22736/22801 patches
# Processed 22740/22801 patches
# Processed 22744/22801 patches
# Processed 22748/22801 patches
# Processed 22752/22801 patches
# Processed 22756/22801 patches
# Processed 22760/22801 patches
# Processed 22764/22801 patches
# Processed 22768/22801 patches
# Processed 22772/22801 patches
# Processed 22776/22801 patches
# Processed 22780/22801 patches
# Processed 22784/22801 patches
# Processed 22788/22801 patches
# Processed 22792/22801 patches
# Processed 22796/22801 patches
# Processed 22800/22801 patches
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_560']
# Received: inputs=Tensor(shape=(None, 128, 128, 3))
#   warnings.warn(msg)
# Processed 22801/22801 patches

# %%
# !zip -r /kaggle/working/arteries.zip /kaggle/working/out_art
# !zip -r /kaggle/working/veins.zip /kaggle/working/out_vei
# !zip -r /kaggle/working/pvbm.zip /kaggle/working/PVBM_datasets/INSPIRE

# %%
from PVBM.DiscSegmenter import DiscSegmenter

# Initialize the segmenter
segmenter = DiscSegmenter()

# Define the segmentation path and replace specific parts of the path
image_path = '../PVBM_datasets/INSPIRE/images/image13.png'
# Extract the segmentation
optic_disc = segmenter.segment(image_path=image_path)
#Extract the optic disc features
center, radius, roi, zones_ABC = segmenter.post_processing(segmentation=optic_disc, max_roi_size = 600)

# %%
print(center,radius)

# %%
for i in os.listdir('/kaggle/working/PVBM_datasets/INSPIRE/images'):
 try:
    from PVBM.DiscSegmenter import DiscSegmenter
    
    # Initialize the segmenter
    segmenter = DiscSegmenter()
    
    # Define the segmentation path and replace specific parts of the path
    image_path = '../PVBM_datasets/INSPIRE/images/'+i
    # Extract the segmentation
    optic_disc = segmenter.segment(image_path=image_path)
    #Extract the optic disc features
    center, radius, roi, zones_ABC = segmenter.post_processing(segmentation=optic_disc, max_roi_size = 600)
    from PVBM.CentralRetinalAnalysis import CREVBMs
    import numpy as np
    from skimage.morphology import skeletonize
    from PIL import Image
    #Preprocessing and roi extraction
    creVBMs = CREVBMs()
    
    ####Artery
    blood_vessel_segmentation_path = '/kaggle/working/out_art/'+i
    segmentation = np.array(Image.open(blood_vessel_segmentation_path))/255 #Open the segmentation
    # plt.imshow(segmentation, cmap="gray")
    skeleton = skeletonize(segmentation)*1
    segmentation_roi, skeleton_roi = creVBMs.apply_roi(
        segmentation=segmentation,
        skeleton=skeleton,
        zones_ABC=zones_ABC
    )
    out,_ = creVBMs.compute_central_retinal_equivalents(
        blood_vessel=segmentation_roi.copy(),
        skeleton=skeleton_roi.copy(),
        xc=center[0],
        yc=center[1],
        radius=radius,
        artery = True,
        Toplot = False #This allows to generate the CRE visualisation but require a lot of RAM
        # If you are only interested about the VBMs values then set Toplot to False
    )
    craek, craeh = out["craek"], out["craeh"]
    
    ####Veins
    blood_vessel_segmentation_path = '/kaggle/working/out_vei/'+i
    segmentation = np.array(Image.open(blood_vessel_segmentation_path))/255 #Open the segmentation
    skeleton = skeletonize(segmentation)*1
    segmentation_roi, skeleton_roi = creVBMs.apply_roi(
        segmentation=segmentation,
        skeleton=skeleton,
        zones_ABC=zones_ABC
    )
    out,_ = creVBMs.compute_central_retinal_equivalents(
        blood_vessel=segmentation_roi.copy(),
        skeleton=skeleton_roi.copy(),
        xc=center[0],
        yc=center[1],
        radius=radius,
        artery = False,
        Toplot = False #This allows to generate the CRE visualisation but require a lot of RAM
        # If you are only interested about the VBMs values then set Toplot to False
    )
    crvek, crveh = out["crvek"], out["crveh"]
    
    AVR_h = craeh/crveh
    AVR_k = craek/crvek
    
    print(i,f"CRAE_H: {craeh}, CRAE_K: {craek},CRVE_H: {crveh}, CRVE_K: {crvek}, AVR_H: {AVR_h}, AVR_K: {AVR_k} ")
 except:
     print(i,"failed")

# %%
from PVBM.DiscSegmenter import DiscSegmenter

# Initialize the segmenter
segmenter = DiscSegmenter()

# Define the segmentation path and replace specific parts of the path
image_path = '../PVBM_datasets/INSPIRE/images/image13.png'
# Extract the segmentation
optic_disc = segmenter.segment(image_path=image_path)
#Extract the optic disc features
center, radius, roi, zones_ABC = segmenter.post_processing(segmentation=optic_disc, max_roi_size = 600)

# %%
### First run the optic disc segmentation snippet to extract center, radius, roi, zones_ABC
for i in os.listdir('/kaggle/working/PVBM_datasets/INSPIRE/images'):
    from PVBM.DiscSegmenter import DiscSegmenter
    
    # Initialize the segmenter
    segmenter = DiscSegmenter()
    
    # Define the segmentation path and replace specific parts of the path
    image_path = '../PVBM_datasets/INSPIRE/images/'+i
    # Extract the segmentation
    optic_disc = segmenter.segment(image_path=image_path)
    #Extract the optic disc features
    center, radius, roi, zones_ABC = segmenter.post_processing(segmentation=optic_disc, max_roi_size = 600)
   
    from PVBM.CentralRetinalAnalysis import CREVBMs
    import numpy as np
    from skimage.morphology import skeletonize
    from PIL import Image
    #Preprocessing and roi extraction
    creVBMs = CREVBMs()
    
    ####Artery
    blood_vessel_segmentation_path = '../PVBM_datasets/INSPIRE/artery/'+i
    segmentation = np.array(Image.open(blood_vessel_segmentation_path))/255 #Open the segmentation
    skeleton = skeletonize(segmentation)*1
    segmentation_roi, skeleton_roi = creVBMs.apply_roi(
        segmentation=segmentation,
        skeleton=skeleton,
        zones_ABC=zones_ABC
    )
    out,_ = creVBMs.compute_central_retinal_equivalents(
        blood_vessel=segmentation_roi.copy(),
        skeleton=skeleton_roi.copy(),
        xc=center[0],
        yc=center[1],
        radius=radius,
        artery = True,
        Toplot = False #This allows to generate the CRE visualisation but require a lot of RAM
        # If you are only interested about the VBMs values then set Toplot to False
    )
    craek, craeh = out["craek"], out["craeh"]
    
    ####Veins
    blood_vessel_segmentation_path = '../PVBM_datasets/INSPIRE/veins/'+i
    segmentation = np.array(Image.open(blood_vessel_segmentation_path))/255 #Open the segmentation
    skeleton = skeletonize(segmentation)*1
    segmentation_roi, skeleton_roi = creVBMs.apply_roi(
        segmentation=segmentation,
        skeleton=skeleton,
        zones_ABC=zones_ABC
    )
    out,_ = creVBMs.compute_central_retinal_equivalents(
        blood_vessel=segmentation_roi.copy(),
        skeleton=skeleton_roi.copy(),
        xc=center[0],
        yc=center[1],
        radius=radius,
        artery = False,
        Toplot = False #This allows to generate the CRE visualisation but require a lot of RAM
        # If you are only interested about the VBMs values then set Toplot to False
    )
    crvek, crveh = out["crvek"], out["crveh"]
    
    AVR_h = craeh/crveh
    AVR_k = craek/crvek
    
    print(i,f"CRAE_H: {craeh}, CRAE_K: {craek},CRVE_H: {crveh}, CRVE_K: {crvek}, AVR_H: {AVR_h}, AVR_K: {AVR_k} ")

# %%
import matplotlib.pyplot as plt
